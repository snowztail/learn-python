# %% [markdown]
# # Optimisation: Compilation
#
# Compilation is the act of a program, known as a compiler, examining source code and creating a new piece of executable code which may be executed later. Compilation offers a few useful advantages. A compiler can check the syntax of all the code of a program before it is run, which can aid finding problems in the code. Of more immediate use to us, however, is the fact that compilers can interpret our code and write a more efficient piece of code in a lower level language which is guaranteed to produce the same result. This is the property of compilation that we can use to speed up code written in Python.
#
# Some languages are, by default, compiled languages, such as Fortran and C. Code written in these languages are usually compiled before they are run. In these cases, a separate exceutable file is normally created and this is what is run, without reference to the source code at all.
#
# Python code can be compiled this way, but there are other, more convenient ways of using the idea of compilation to speed up Python code.
#
# ## Numba
#
# [Numba](http://numba.pydata.org/) is an example of a Python tool which harnesses the power of compilation to speed up existing Python code with minimal changes to code required. Many of the features in Numba are accessed by adding various decorators to functions. Let's look at a simple example now.
#
# The following example is taken from a series of short examples from the [Numba website](https://numba.pydata.org/). The first code calcualtes the value of $\pi$ using the same method we used in the Parallelism notebook. In the second code cell we import the ```jit``` decorator from the ```numba``` package and add the decorator ```@jit(nopython=True)``` to the function. This causes Numba to compile the function just before it's run and for Python to run the compiled function. Here, ```jit``` stands for "just in time" as the compilation is happening just before the function is run. The ```nonpython = true``` forces Numba to attempt to compile the function using faster, non-Python, code.
#
# If you're running this Jupyter Notebook on your computer, as opposed to Colab, you may need to install the Numba package before you can run the code.

# %%
import random
import cProfile

def monte_carlo_pi(nsamples):
    acc = 0
    for i in range(nsamples):
        x = random.random()
        y = random.random()
        if (x ** 2 + y ** 2) < 1.0:
            acc += 1
    return 4.0 * acc / nsamples

cProfile.run('print(monte_carlo_pi(10000000))')
# Out:
# 3.1422624
#          20000039 function calls in 11.381 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    9.147    9.147   11.379   11.379 <ipython-input-1-c431711fad5c>:4(monte_carlo_pi)
#         1    0.000    0.000   11.380   11.380 <string>:1(<module>)
#         3    0.000    0.000    0.002    0.001 iostream.py:195(schedule)
#         2    0.000    0.000    0.000    0.000 iostream.py:307(_is_master_process)
#         2    0.000    0.000    0.001    0.001 iostream.py:320(_schedule_flush)
#         2    0.000    0.000    0.002    0.001 iostream.py:382(write)
#         3    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#         3    0.002    0.001    0.002    0.001 socket.py:540(send)
#         3    0.000    0.000    0.000    0.000 threading.py:1050(_wait_for_tstate_lock)
#         3    0.000    0.000    0.000    0.000 threading.py:1092(is_alive)
#         3    0.000    0.000    0.000    0.000 threading.py:507(is_set)
#         1    0.000    0.000   11.381   11.381 {built-in method builtins.exec}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.002    0.002 {built-in method builtins.print}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#  20000000    2.232    0.000    2.232    0.000 {method 'random' of '_random.Random' objects}

# %%
# Import the jit decorator from the numba package
from numba import jit
import random
import cProfile

# Apply the jit decorator to our function
@jit(nopython=True)
def monte_carlo_pi(nsamples):
    acc = 0
    for i in range(nsamples):
        x = random.random()
        y = random.random()
        if (x ** 2 + y ** 2) < 1.0:
            acc += 1
    return 4.0 * acc / nsamples

cProfile.run('monte_carlo_pi(10000000)')
# Out:
#          481993 function calls (455514 primitive calls) in 1.068 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       976    0.001    0.000    0.003    0.000 <__array_function__ internals>:2(can_cast)
# 1924/1253    0.002    0.000    0.146    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#       147    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:103(release)
#       116    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#       116    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:147(__enter__)
#       116    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:151(__exit__)
#       147    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:157(_get_module_lock)
#       115    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:176(cb)
#        31    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:194(_lock_unlock_module)
#    179/27    0.000    0.000    0.142    0.005 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#       754    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:222(_verbose_message)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:232(_requires_builtin_wrapper)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:269(_module_repr)
#       112    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:307(__init__)
#       112    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:311(__enter__)
#       112    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:318(__exit__)
#       448    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:321(<genexpr>)
#        94    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:35(_new_module)
#       115    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:369(__init__)
#       205    0.000    0.000    0.002    0.000 <frozen importlib._bootstrap>:403(cached)
#       329    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#       118    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:424(has_location)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:433(spec_from_loader)
#       112    0.001    0.000    0.003    0.000 <frozen importlib._bootstrap>:504(_init_module_attrs)
#       112    0.000    0.000    0.020    0.000 <frozen importlib._bootstrap>:576(module_from_spec)
#       115    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:58(__init__)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:593(_module_repr_from_spec)
#    112/27    0.001    0.000    0.138    0.005 <frozen importlib._bootstrap>:663(_load_unlocked)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:710(module_repr)
#       115    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:719(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:740(create_module)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:748(exec_module)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:765(is_package)
#       147    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:78(acquire)
#       114    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:792(find_spec)
#       809    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:855(__enter__)
#       809    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:859(__exit__)
#       463    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:873(_find_spec_legacy)
#       115    0.002    0.000    0.015    0.000 <frozen importlib._bootstrap>:882(_find_spec)
#    116/27    0.001    0.000    0.144    0.005 <frozen importlib._bootstrap>:948(_find_and_load_unlocked)
#    116/27    0.001    0.000    0.144    0.005 <frozen importlib._bootstrap>:978(_find_and_load)
#        17    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1029(__init__)
#        17    0.000    0.000    0.016    0.001 <frozen importlib._bootstrap_external>:1040(create_module)
#     17/14    0.000    0.000    0.008    0.001 <frozen importlib._bootstrap_external>:1048(exec_module)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1190(_path_hooks)
#       126    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1203(_path_importer_cache)
#       114    0.000    0.000    0.011    0.000 <frozen importlib._bootstrap_external>:1240(_get_spec)
#       114    0.000    0.000    0.011    0.000 <frozen importlib._bootstrap_external>:1272(find_spec)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1319(__init__)
#        56    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1325(<genexpr>)
#       111    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1351(_get_spec)
#       122    0.001    0.000    0.010    0.000 <frozen importlib._bootstrap_external>:1356(find_spec)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1404(_fill_cache)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1445(path_hook_for_FileFinder)
#       188    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:271(cache_from_source)
#       111    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:369(_get_cached)
#       122    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:40(_relax_case)
#        94    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:401(_check_name_wrapper)
#        94    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:438(_classify_pyc)
#        94    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:471(_validate_timestamp_pyc)
#       282    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:51(_r_long)
#        94    0.000    0.000    0.017    0.000 <frozen importlib._bootstrap_external>:523(_compile_bytecode)
#       643    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:56(_path_join)
#       111    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:574(spec_from_file_location)
#       643    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:58(<listcomp>)
#       188    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:62(_path_split)
#        94    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:719(create_module)
#     94/27    0.000    0.000    0.137    0.005 <frozen importlib._bootstrap_external>:722(exec_module)
#       355    0.000    0.000    0.006    0.000 <frozen importlib._bootstrap_external>:74(_path_stat)
#        94    0.001    0.000    0.043    0.000 <frozen importlib._bootstrap_external>:793(get_code)
#       139    0.000    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:84(_path_is_mode_type)
#        94    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:884(__init__)
#        94    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:909(get_filename)
#        94    0.004    0.000    0.022    0.000 <frozen importlib._bootstrap_external>:914(get_data)
#       132    0.000    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:93(_path_isfile)
#        94    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:951(path_stats)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:98(_path_isdir)
#         1    0.301    0.301    0.301    0.301 <ipython-input-2-37747d820d0d>:7(monte_carlo_pi)
#         1    0.004    0.004    1.068    1.068 <string>:1(<module>)
#       356    0.000    0.000    0.000    0.000 <string>:1(__new__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1(<module>)
#         1    0.000    0.000    0.017    0.017 __init__.py:10(<module>)
#      1793    0.001    0.000    0.002    0.000 __init__.py:1356(debug)
#         1    0.000    0.000    0.005    0.005 __init__.py:151(<module>)
#         3    0.000    0.000    0.000    0.000 __init__.py:1600(getEffectiveLevel)
#      1793    0.001    0.000    0.001    0.000 __init__.py:1614(isEnabledFor)
#         1    0.000    0.000    0.045    0.045 __init__.py:189(<module>)
#         3    0.000    0.000    0.000    0.000 __init__.py:212(_acquireLock)
#         1    0.000    0.000    0.000    0.000 __init__.py:215(<listcomp>)
#         1    0.000    0.000    0.021    0.021 __init__.py:219(<module>)
#         3    0.000    0.000    0.000    0.000 __init__.py:221(_releaseLock)
#         3    0.000    0.000    0.000    0.000 __init__.py:24(_module_matches_namespace)
#         1    0.000    0.000    0.000    0.000 __init__.py:244(<listcomp>)
#        54    0.000    0.000    0.004    0.000 __init__.py:276(__getattr__)
#       392    0.000    0.000    0.000    0.000 __init__.py:2848(get_entry_map)
#         7    0.001    0.000    0.002    0.000 __init__.py:316(namedtuple)
#        61    0.000    0.000    0.000    0.000 __init__.py:388(<genexpr>)
#         1    0.000    0.000    0.000    0.000 __init__.py:4(<module>)
#         4    0.000    0.000    0.000    0.000 __init__.py:47(create_string_buffer)
#        16    0.000    0.000    0.000    0.000 __init__.py:497(cast)
#         2    0.000    0.000    0.000    0.000 __init__.py:501(string_at)
#        10    0.000    0.000    0.000    0.000 __init__.py:550(__init__)
#         3    0.000    0.000    0.000    0.000 __init__.py:57(find_spec)
#         1    0.000    0.000    0.000    0.000 __init__.py:570(__missing__)
#        10    0.000    0.000    0.000    0.000 __init__.py:619(update)
#         1    0.000    0.000    0.000    0.000 __init__.py:631(iter_entry_points)
#         1    0.000    0.000    0.001    0.001 __init__.py:639(<genexpr>)
#       393    0.000    0.000    0.000    0.000 __init__.py:653(__iter__)
#         1    0.000    0.000    0.003    0.003 __init__.py:7(<module>)
#       115    0.000    0.000    0.000    0.000 _altair.py:25(find_module)
#       115    0.000    0.000    0.000    0.000 _bokeh.py:36(find_module)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:252(__subclasshook__)
#        13    0.000    0.000    0.000    0.000 _collections_abc.py:302(__subclasshook__)
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:392(__subclasshook__)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:672(keys)
#         4    0.000    0.000    0.000    0.000 _collections_abc.py:676(items)
#         6    0.000    0.000    0.000    0.000 _collections_abc.py:698(__init__)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:701(__len__)
#        26    0.000    0.000    0.000    0.000 _collections_abc.py:719(__iter__)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:72(_check_methods)
#       114    0.000    0.000    0.001    0.000 _collections_abc.py:742(__iter__)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:879(__iter__)
#       115    0.000    0.000    0.000    0.000 _cv2.py:70(find_module)
#         1    0.000    0.000    0.000    0.000 _decomp_ldl.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _decomp_polar.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _decomp_qz.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _expm_frechet.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _index.py:2(<module>)
#         1    0.000    0.000    0.000    0.000 _index.py:30(IndexMixin)
#         1    0.000    0.000    0.000    0.000 _laplacian.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 _matfuncs_sqrtm.py:22(SqrtmError)
#         1    0.000    0.000    0.000    0.000 _matfuncs_sqrtm.py:6(<module>)
#         1    0.000    0.000    0.000    0.000 _matrix_io.py:1(<module>)
#         1    0.000    0.000    0.004    0.004 _numpy_compat.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 _procrustes.py:4(<module>)
#       115    0.000    0.000    0.000    0.000 _pydrive.py:31(find_module)
#         1    0.000    0.000    0.000    0.000 _pytesttester.py:78(__init__)
#         1    0.000    0.000    0.022    0.022 _sketches.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _solvers.py:1(<module>)
#         3    0.000    0.000    0.000    0.000 _testutils.py:26(__init__)
#         1    0.000    0.000    0.000    0.000 _util.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _util.py:139(DeprecatedImport)
#         2    0.000    0.000    0.000    0.000 _util.py:157(__init__)
#         1    0.000    0.000    0.000    0.000 _util.py:350(MapWrapper)
#      2849    0.001    0.000    0.001    0.000 _utils.py:13(is_used)
#      1569    0.002    0.000    0.007    0.000 _utils.py:16(register)
#      1501    0.003    0.000    0.005    0.000 _utils.py:24(deduplicate)
# 3931/1588    0.011    0.000    0.037    0.000 _utils.py:44(__str__)
# 2889/2877    0.004    0.000    0.011    0.000 _utils.py:54(get_reference)
#        17    0.000    0.000    0.000    0.000 _utils.py:64(set_metadata)
#      1171    0.000    0.000    0.000    0.000 _utils.py:71(_stringify_metadata)
#        17    0.000    0.000    0.000    0.000 _utils.py:76(<listcomp>)
#        71    0.000    0.000    0.000    0.000 _utils.py:9(__init__)
#         1    0.000    0.000    0.001    0.001 _validation.py:1(<module>)
#         7    0.000    0.000    0.001    0.000 _version.py:114(_compare)
#         2    0.000    0.000    0.000    0.000 _version.py:148(__gt__)
#         5    0.000    0.000    0.000    0.000 _version.py:151(__ge__)
#        14    0.000    0.000    0.001    0.000 _version.py:55(__init__)
#        14    0.000    0.000    0.000    0.000 _version.py:62(<listcomp>)
#         2    0.000    0.000    0.000    0.000 _version.py:70(<listcomp>)
#         7    0.000    0.000    0.000    0.000 _version.py:78(_compare_version)
#       537    0.001    0.000    0.013    0.000 abc.py:125(__new__)
#      6360    0.002    0.000    0.017    0.000 abc.py:137(__instancecheck__)
# 2245/1302    0.001    0.000    0.012    0.000 abc.py:141(__subclasscheck__)
#       493    0.000    0.000    0.000    0.000 abstract.py:115(__repr__)
# 2689/2431    0.003    0.000    0.005    0.000 abstract.py:118(__hash__)
# 4343/4160    0.004    0.000    0.025    0.000 abstract.py:121(__eq__)
#       128    0.000    0.000    0.000    0.000 abstract.py:124(__ne__)
#       326    0.000    0.000    0.000    0.000 abstract.py:155(is_precise)
#         2    0.000    0.000    0.000    0.000 abstract.py:174(__call__)
#       691    0.000    0.000    0.001    0.000 abstract.py:19(_autoincr)
#         4    0.000    0.000    0.000    0.000 abstract.py:250(unify)
#       202    0.000    0.000    0.000    0.000 abstract.py:27(_on_type_disposal)
#        11    0.000    0.000    0.000    0.000 abstract.py:424(_literal_init)
#        22    0.000    0.000    0.000    0.000 abstract.py:435(literal_value)
#       135    0.000    0.000    0.001    0.000 abstract.py:439(literal_type)
#       880    0.002    0.000    0.005    0.000 abstract.py:48(_intern)
#   880/878    0.002    0.000    0.014    0.000 abstract.py:60(__call__)
#       880    0.000    0.000    0.000    0.000 abstract.py:93(__init__)
#      4831    0.021    0.000    0.021    0.000 abstract.py:96(key)
#        22    0.004    0.000    0.009    0.000 analysis.py:118(compute_dead_maps)
#       593    0.000    0.000    0.001    0.000 analysis.py:138(<genexpr>)
#       428    0.000    0.000    0.000    0.000 analysis.py:141(<genexpr>)
#       300    0.000    0.000    0.000    0.000 analysis.py:182(<genexpr>)
#        22    0.002    0.000    0.003    0.000 analysis.py:190(compute_live_variables)
#        70    0.000    0.000    0.000    0.000 analysis.py:200(fix_point_progress)
#        22    0.008    0.000    0.038    0.002 analysis.py:23(compute_use_defs)
#        59    0.002    0.000    0.009    0.000 analysis.py:235(compute_cfg_from_blocks)
#         4    0.000    0.000    0.002    0.001 analysis.py:291(dead_branch_prune)
#         4    0.000    0.000    0.001    0.000 analysis.py:304(find_branches)
#         2    0.000    0.000    0.000    0.000 analysis.py:322(do_prune)
#         2    0.000    0.000    0.000    0.000 analysis.py:360(prune_by_predicate)
#         4    0.000    0.000    0.000    0.000 analysis.py:375(Unknown)
#         2    0.000    0.000    0.000    0.000 analysis.py:378(resolve_input_arg_const)
#      1380    0.000    0.000    0.000    0.000 analysis.py:40(<genexpr>)
#         4    0.000    0.000    0.000    0.000 analysis.py:478(<listcomp>)
#         2    0.000    0.000    0.000    0.000 analysis.py:509(rewrite_semantic_constants)
#        53    0.000    0.000    0.000    0.000 analysis.py:536(rewrite_array_ndim)
#        53    0.000    0.000    0.000    0.000 analysis.py:546(rewrite_tuple_len)
#         2    0.000    0.000    0.000    0.000 analysis.py:575(find_literally_calls)
#        22    0.000    0.000    0.012    0.001 analysis.py:60(compute_live_map)
#       219    0.001    0.000    0.002    0.000 analysis.py:66(fix_point_progress)
#      2821    0.001    0.000    0.001    0.000 analysis.py:69(<genexpr>)
#        44    0.000    0.000    0.011    0.000 analysis.py:71(fix_point)
#        66    0.003    0.000    0.004    0.000 analysis.py:81(def_reach)
#       109    0.003    0.000    0.005    0.000 analysis.py:91(liveness)
#        75    0.000    0.000    0.001    0.000 api.py:194(typeof)
#         1    0.000    0.000    0.000    0.000 api.py:293(cast)
#         1    0.000    0.000    0.031    0.031 api.py:41(__init__)
#         2    0.000    0.000    0.000    0.000 api.py:433(_get_cached_btype)
#        72    0.000    0.000    0.000    0.000 api.py:952(_builtin_function_type)
#         2    0.000    0.000    0.000    0.000 array_exprs.py:26(__init__)
#        24    0.000    0.000    0.001    0.000 array_exprs.py:33(match)
#         1    0.000    0.000    0.001    0.001 arraydecl.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:160(GetItemBuffer)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:169(SetItemBuffer)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:234(ArrayAttribute)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:497(DTypeAttr)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:514(StaticGetItemArray)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:528(RecordAttribute)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:537(StaticGetItemRecord)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:553(StaticGetItemLiteralRecord)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:567(StaticSetItemRecord)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:580(StaticSetItemLiteralRecord)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:594(ArrayCTypesAttribute)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:602(ArrayFlagsAttribute)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:616(NestedArrayAttribute)
#        11    0.000    0.000    0.000    0.000 arraydecl.py:747(install_array_method)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:783(CmpOpEqArray)
#         2    0.000    0.000    0.000    0.000 arraymath.py:1059(_compute_current_val_impl_gen)
#         2    0.000    0.000    0.000    0.000 arraymath.py:1151(_partition_factory)
#         2    0.000    0.000    0.000    0.000 arraymath.py:1192(_select_factory)
#         2    0.000    0.000    0.000    0.000 arraymath.py:2125(np_interp_impl_complex_fp_inner_factory)
#         2    0.000    0.000    0.000    0.000 arraymath.py:2339(np_interp_impl_inner_factory)
#         1    0.001    0.001    0.058    0.058 arraymath.py:3(<module>)
#         1    0.000    0.000    0.045    0.045 arraymath.py:31(_check_blas)
#         2    0.000    0.000    0.000    0.000 arraymath.py:3503(_searchsorted)
#         2    0.000    0.000    0.000    0.000 arraymath.py:3816(generate_xinfo)
#         1    0.000    0.000    0.000    0.000 arraymath.py:3872(_corr_conv_Mode)
#         4    0.000    0.000    0.000    0.000 arraymath.py:4182(window_generator)
#         4    0.000    0.000    0.000    0.000 arraymath.py:834(nan_min_max_factory)
#         2    0.000    0.000    0.000    0.000 arrayobj.py:5129(ol_bool)
#         1    0.000    0.000    0.000    0.000 ast_transforms.py:10(<module>)
#         1    0.000    0.000    0.005    0.005 base.py:1(<module>)
#        46    0.000    0.000    0.000    0.000 base.py:104(<lambda>)
#       718    0.002    0.000    0.010    0.000 base.py:107(_match_arglist)
#        33    0.000    0.000    0.011    0.000 base.py:1096(get_abi_sizeof)
#        38    0.000    0.000    0.000    0.000 base.py:1126(active_code_library)
#         4    0.000    0.000    0.000    0.000 base.py:1132(push_code_library)
#        35    0.000    0.000    0.000    0.000 base.py:1142(add_linking_libs)
#        35    0.000    0.000    0.003    0.000 base.py:1157(__init__)
#     35/13    0.000    0.000    0.325    0.025 base.py:1163(__call__)
#        35    0.000    0.000    0.000    0.000 base.py:1168(__getattr__)
#        35    0.000    0.000    0.003    0.000 base.py:1174(_has_loc)
#        35    0.000    0.000    0.000    0.000 base.py:1183(__init__)
#        35    0.000    0.000    0.003    0.000 base.py:1186(__call__)
#     35/13    0.000    0.000    0.325    0.025 base.py:1192(wrapper)
#       811    0.002    0.000    0.007    0.000 base.py:127(_match)
#      1298    0.002    0.000    0.002    0.000 base.py:142(append)
#         1    0.000    0.000    0.000    0.000 base.py:16(SparseWarning)
#         1    0.000    0.000    0.000    0.000 base.py:20(SparseFormatWarning)
#         1    0.000    0.000    0.000    0.000 base.py:24(SparseEfficiencyWarning)
#         2    0.000    0.000    0.102    0.051 base.py:266(refresh)
#         4    0.000    0.000    0.000    0.000 base.py:293(mangler)
#         4    0.000    0.000    0.000    0.000 base.py:299(get_env_name)
#         3    0.000    0.000    0.000    0.000 base.py:307(declare_env_global)
#        16    0.000    0.000    0.001    0.000 base.py:328(get_arg_packer)
#         1    0.000    0.000    0.000    0.000 base.py:338(nonconst_module_attrs)
#         1    0.000    0.000    0.002    0.002 base.py:345(nrt)
#         4    0.000    0.000    0.000    0.000 base.py:350(subtarget)
#        14    0.000    0.000    0.005    0.000 base.py:361(install_registry)
#        14    0.001    0.000    0.004    0.000 base.py:377(insert_func_defn)
#        14    0.000    0.000    0.000    0.000 base.py:381(_insert_getattr_defn)
#        14    0.000    0.000    0.000    0.000 base.py:385(_insert_setattr_defn)
#        14    0.000    0.000    0.000    0.000 base.py:389(_insert_cast_defn)
#        14    0.000    0.000    0.000    0.000 base.py:393(_insert_get_constant_defn)
#         1    0.000    0.000    0.000    0.000 base.py:397(insert_user_function)
#       574    0.000    0.000    0.000    0.000 base.py:41(__init__)
#         4    0.000    0.000    0.002    0.000 base.py:428(declare_function)
#         5    0.000    0.000    0.001    0.000 base.py:444(insert_const_string)
#       102    0.000    0.000    0.013    0.000 base.py:46(find)
#        17    0.000    0.000    0.001    0.000 base.py:464(insert_unique_const)
#         8    0.000    0.000    0.000    0.000 base.py:476(get_argument_type)
#       151    0.000    0.000    0.002    0.000 base.py:492(get_value_type)
#        50    0.000    0.000    0.006    0.000 base.py:513(get_constant_generic)
#         6    0.000    0.000    0.000    0.000 base.py:523(get_constant)
#        44    0.000    0.000    0.012    0.000 base.py:53(_find)
#     37/35    0.000    0.000    0.008    0.000 base.py:539(get_function)
#         3    0.000    0.000    0.000    0.000 base.py:590(get_getattr)
#        44    0.001    0.000    0.011    0.000 base.py:60(_select_compatible)
#         1    0.000    0.000    0.000    0.000 base.py:62(spmatrix)
#         4    0.000    0.000    0.000    0.000 base.py:666(get_returned_value)
#         4    0.000    0.000    0.000    0.000 base.py:672(get_return_value)
#         1    0.000    0.000    0.000    0.000 base.py:689(pair_first)
#         1    0.000    0.000    0.000    0.000 base.py:696(pair_second)
#        42    0.000    0.000    0.001    0.000 base.py:70(_best_signature)
#   151/140    0.000    0.000    0.005    0.000 base.py:703(cast)
#         6    0.000    0.000    0.000    0.000 base.py:757(get_c_value)
#         8    0.000    0.000    0.000    0.000 base.py:78(<lambda>)
#         1    0.000    0.000    0.000    0.000 base.py:807(get_struct_type)
#         1    0.000    0.000    0.000    0.000 base.py:811(<listcomp>)
#        19    0.000    0.000    0.000    0.000 base.py:814(get_dummy_value)
#        19    0.000    0.000    0.000    0.000 base.py:817(get_dummy_type)
#         1    0.000    0.000    0.311    0.311 base.py:820(_compile_subroutine_no_cache)
#         2    0.000    0.000    0.311    0.156 base.py:850(compile_subroutine)
#         8    0.000    0.000    0.000    0.000 base.py:866(<genexpr>)
#        42    0.000    0.000    0.001    0.000 base.py:87(_sort_signatures)
#         2    0.000    0.000    0.314    0.157 base.py:879(compile_internal)
#         2    0.000    0.000    0.003    0.001 base.py:887(call_internal)
#         2    0.000    0.000    0.002    0.001 base.py:899(call_internal_no_propagate)
#         6    0.000    0.000    0.001    0.000 base.py:957(get_python_api)
#         3    0.000    0.000    0.000    0.000 base.py:973(get_helper_class)
#         3    0.000    0.000    0.001    0.000 base.py:981(_make_helper)
#         3    0.000    0.000    0.001    0.000 base.py:985(make_helper)
#         1    0.000    0.000    0.003    0.003 basic.py:7(<module>)
#         1    0.000    0.000    0.005    0.005 blas.py:202(<module>)
#         1    0.000    0.000    0.000    0.000 blas.py:233(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 blas.py:234(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 blas.py:365(_memoize_get_funcs)
#         1    0.000    0.000    0.001    0.001 boxing.py:44(unbox_integer)
#         1    0.000    0.000    0.000    0.000 boxing.py:60(box_float)
#         1    0.000    0.000    0.000    0.000 bsr.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 bsr.py:24(bsr_matrix)
#         1    0.000    0.000    0.000    0.000 bufproto.py:3(<module>)
#        12    0.000    0.000    0.000    0.000 builder.py:147(wrapped)
#        57    0.000    0.000    0.000    0.000 builder.py:160(_label_suffix)
#         4    0.000    0.000    0.000    0.000 builder.py:177(__init__)
#        83    0.000    0.000    0.001    0.000 builder.py:18(wrapped)
#      1855    0.001    0.000    0.001    0.000 builder.py:182(block)
#       214    0.000    0.000    0.000    0.000 builder.py:191(function)
#         8    0.000    0.000    0.000    0.000 builder.py:198(module)
#         4    0.000    0.000    0.000    0.000 builder.py:205(position_before)
#       333    0.000    0.000    0.000    0.000 builder.py:228(position_at_end)
#        59    0.000    0.000    0.001    0.000 builder.py:235(append_basic_block)
#       252    0.000    0.000    0.001    0.000 builder.py:251(goto_block)
#       248    0.001    0.000    0.003    0.000 builder.py:268(goto_entry_block)
#        58    0.000    0.000    0.000    0.000 builder.py:277(_branch_helper)
#        54    0.000    0.000    0.004    0.000 builder.py:284(if_then)
#         2    0.000    0.000    0.000    0.000 builder.py:307(if_else)
#      1264    0.002    0.000    0.002    0.000 builder.py:338(_insert)
#        89    0.000    0.000    0.000    0.000 builder.py:344(_set_terminator)
#         6    0.000    0.000    0.000    0.000 builder.py:526(not_)
#         2    0.000    0.000    0.000    0.000 builder.py:537(neg)
#        46    0.000    0.000    0.001    0.000 builder.py:548(_icmp)
#        27    0.000    0.000    0.001    0.000 builder.py:559(icmp_signed)
#        19    0.000    0.000    0.001    0.000 builder.py:568(icmp_unsigned)
#         3    0.000    0.000    0.000    0.000 builder.py:577(fcmp_ordered)
#         6    0.000    0.000    0.000    0.000 builder.py:609(select)
#       125    0.000    0.000    0.003    0.000 builder.py:717(alloca)
#       391    0.001    0.000    0.008    0.000 builder.py:735(load)
#       406    0.001    0.000    0.009    0.000 builder.py:748(store)
#        36    0.000    0.000    0.001    0.000 builder.py:805(branch)
#        36    0.000    0.000    0.001    0.000 builder.py:813(cbranch)
#        17    0.000    0.000    0.001    0.000 builder.py:837(ret)
#        34    0.000    0.000    0.002    0.000 builder.py:854(call)
#        32    0.000    0.000    0.001    0.000 builder.py:897(gep)
#        38    0.000    0.000    0.001    0.000 builder.py:942(extract_value)
#         3    0.000    0.000    0.000    0.000 builtins.py:109(generic)
#         1    0.000    0.000    0.000    0.000 builtins.py:261(int_impl)
#         2    0.000    0.000    0.001    0.000 builtins.py:298(number_constructor)
#        16    0.000    0.000    0.000    0.000 builtins.py:317(constant_dummy)
#         2    0.000    0.000    0.000    0.000 builtins.py:409(bool_sequence)
#        10    0.000    0.000    0.000    0.000 builtins.py:425(bool_none)
#         6    0.000    0.000    0.000    0.000 builtins.py:444(generic)
#         4    0.000    0.000    0.000    0.000 builtins.py:793(resolve___call__)
#         4    0.000    0.000    0.000    0.000 builtins.py:799(typer)
#        17    0.000    0.000    0.000    0.000 builtins.py:913(generic)
#         2    0.000    0.000    0.000    0.000 builtins.py:941(generic)
#         3    0.000    0.000    0.000    0.000 builtins.py:98(generic)
#         2    0.000    0.000    0.000    0.000 builtins.py:98(none_equality)
#       136    0.000    0.000    0.000    0.000 bytecode.py:120(_unpack_opargs)
#       138    0.000    0.000    0.000    0.000 bytecode.py:148(_patched_opargs)
#         2    0.000    0.000    0.000    0.000 bytecode.py:164(__init__)
#         2    0.000    0.000    0.000    0.000 bytecode.py:168(__iter__)
#       138    0.000    0.000    0.000    0.000 bytecode.py:171(_fetch_opcode)
#       138    0.000    0.000    0.001    0.000 bytecode.py:174(next)
#         2    0.000    0.000    0.001    0.001 bytecode.py:196(__init__)
#        16    0.000    0.000    0.000    0.000 bytecode.py:199(<genexpr>)
#         2    0.000    0.000    0.000    0.000 bytecode.py:215(_compute_lineno)
#         2    0.000    0.000    0.000    0.000 bytecode.py:23(get_function_object)
#       569    0.000    0.000    0.000    0.000 bytecode.py:237(__getitem__)
#         2    0.000    0.000    0.000    0.000 bytecode.py:243(dump)
#       136    0.000    0.000    0.000    0.000 bytecode.py:244(label_marker)
#       138    0.000    0.000    0.000    0.000 bytecode.py:250(<genexpr>)
#         2    0.000    0.000    0.000    0.000 bytecode.py:301(from_function)
#         7    0.000    0.000    0.000    0.000 bytecode.py:35(get_code_object)
#       136    0.000    0.000    0.000    0.000 bytecode.py:72(__init__)
#        32    0.000    0.000    0.000    0.000 bytecode.py:80(is_jump)
#        32    0.000    0.000    0.000    0.000 bytecode.py:88(get_jump_target)
#       136    0.000    0.000    0.000    0.000 bytecode.py:96(__repr__)
#         3    0.000    0.000    0.000    0.000 byteflow.py:1027(op_LOAD_METHOD)
#         3    0.000    0.000    0.000    0.000 byteflow.py:1030(op_CALL_METHOD)
#        37    0.000    0.000    0.000    0.000 byteflow.py:1038(__init__)
#       244    0.000    0.000    0.000    0.000 byteflow.py:1075(get_identity)
#       230    0.000    0.000    0.000    0.000 byteflow.py:1078(__hash__)
#         7    0.000    0.000    0.000    0.000 byteflow.py:1084(__eq__)
#       155    0.000    0.000    0.000    0.000 byteflow.py:1087(pc_initial)
#        30    0.000    0.000    0.000    0.000 byteflow.py:1094(instructions)
#        60    0.000    0.000    0.000    0.000 byteflow.py:1101(outgoing_edges)
#        30    0.000    0.000    0.000    0.000 byteflow.py:1111(outgoing_phis)
#        30    0.000    0.000    0.000    0.000 byteflow.py:1120(blockstack_initial)
#        30    0.000    0.000    0.000    0.000 byteflow.py:1136(find_initial_try_block)
#       135    0.000    0.000    0.000    0.000 byteflow.py:1143(has_terminated)
#       408    0.000    0.000    0.000    0.000 byteflow.py:1146(get_inst)
#       110    0.000    0.000    0.000    0.000 byteflow.py:1149(advance_pc)
#       107    0.000    0.000    0.001    0.000 byteflow.py:1153(make_temp)
#       131    0.000    0.000    0.001    0.000 byteflow.py:1171(append)
#         1    0.000    0.000    0.000    0.000 byteflow.py:1176(get_tos)
#         1    0.000    0.000    0.000    0.000 byteflow.py:1179(peek)
#        99    0.000    0.000    0.000    0.000 byteflow.py:1184(push)
#        92    0.000    0.000    0.000    0.000 byteflow.py:1188(pop)
#         2    0.000    0.000    0.000    0.000 byteflow.py:1192(push_block)
#         2    0.000    0.000    0.000    0.000 byteflow.py:1198(reset_stack)
#         2    0.000    0.000    0.000    0.000 byteflow.py:1205(make_block)
#         2    0.000    0.000    0.000    0.000 byteflow.py:1220(pop_block)
#       114    0.000    0.000    0.000    0.000 byteflow.py:1235(get_top_block)
#       110    0.000    0.000    0.000    0.000 byteflow.py:1243(has_active_try)
#        27    0.000    0.000    0.000    0.000 byteflow.py:1248(get_varname)
#        43    0.000    0.000    0.000    0.000 byteflow.py:1253(terminate)
#        35    0.000    0.000    0.000    0.000 byteflow.py:1258(fork)
#         5    0.000    0.000    0.000    0.000 byteflow.py:1281(split_new_block)
#        30    0.000    0.000    0.000    0.000 byteflow.py:1286(get_outgoing_states)
#        30    0.000    0.000    0.000    0.000 byteflow.py:1301(get_outgoing_edgepushed)
#        30    0.000    0.000    0.000    0.000 byteflow.py:1310(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 byteflow.py:1320(__init__)
#        30    0.000    0.000    0.000    0.000 byteflow.py:1323(infos)
#        30    0.000    0.000    0.000    0.000 byteflow.py:1335(adapt_state_infos)
#   340/325    0.000    0.000    0.000    0.000 byteflow.py:1345(_flatten_inst_regs)
#         2    0.000    0.000    0.001    0.001 byteflow.py:1359(__init__)
#       142    0.000    0.000    0.000    0.000 byteflow.py:1382(backbone)
#        36    0.000    0.000    0.000    0.000 byteflow.py:1386(blocks)
#        32    0.000    0.000    0.000    0.000 byteflow.py:1390(iterliveblocks)
#        30    0.000    0.000    0.000    0.000 byteflow.py:1399(__init__)
#       161    0.000    0.000    0.000    0.000 byteflow.py:1401(<genexpr>)
#        30    0.000    0.000    0.000    0.000 byteflow.py:145(<lambda>)
#         2    0.000    0.000    0.000    0.000 byteflow.py:149(_build_cfg)
#         2    0.000    0.000    0.001    0.000 byteflow.py:161(_prune_phis)
#         2    0.000    0.000    0.000    0.000 byteflow.py:169(get_used_phis_per_state)
#         2    0.000    0.000    0.000    0.000 byteflow.py:180(find_use_defs)
#         2    0.000    0.000    0.000    0.000 byteflow.py:193(propagate_phi_map)
#         2    0.000    0.000    0.000    0.000 byteflow.py:215(apply_changes)
#       110    0.000    0.000    0.000    0.000 byteflow.py:238(_is_implicit_new_block)
#         2    0.000    0.000    0.000    0.000 byteflow.py:252(__init__)
#       135    0.001    0.000    0.003    0.000 byteflow.py:260(dispatch)
#         2    0.000    0.000    0.000    0.000 byteflow.py:271(op_NOP)
#         7    0.000    0.000    0.000    0.000 byteflow.py:277(op_LOAD_GLOBAL)
#         5    0.000    0.000    0.000    0.000 byteflow.py:282(op_LOAD_DEREF)
#        21    0.000    0.000    0.000    0.000 byteflow.py:287(op_LOAD_CONST)
#         3    0.000    0.000    0.000    0.000 byteflow.py:292(op_LOAD_ATTR)
#        27    0.000    0.000    0.000    0.000 byteflow.py:298(op_LOAD_FAST)
#        14    0.000    0.000    0.000    0.000 byteflow.py:320(op_STORE_FAST)
#       127    0.000    0.000    0.000    0.000 byteflow.py:36(__init__)
#        57    0.000    0.000    0.000    0.000 byteflow.py:49(__eq__)
#        12    0.000    0.000    0.000    0.000 byteflow.py:555(_op_POP_JUMP_IF)
#         2    0.000    0.000    0.000    0.000 byteflow.py:577(op_JUMP_ABSOLUTE)
#         6    0.000    0.000    0.000    0.000 byteflow.py:588(op_RETURN_VALUE)
#         2    0.000    0.000    0.000    0.000 byteflow.py:598(op_RAISE_VARARGS)
#        14    0.000    0.000    0.000    0.000 byteflow.py:60(__init__)
#         2    0.000    0.000    0.000    0.000 byteflow.py:647(op_SETUP_LOOP)
#         2    0.000    0.000    0.000    0.000 byteflow.py:725(op_POP_BLOCK)
#         2    0.000    0.000    0.001    0.000 byteflow.py:73(__init__)
#         8    0.000    0.000    0.000    0.000 byteflow.py:750(op_CALL_FUNCTION)
#         8    0.000    0.000    0.000    0.000 byteflow.py:752(<listcomp>)
#         2    0.001    0.000    0.007    0.004 byteflow.py:78(run)
#         1    0.000    0.000    0.000    0.000 byteflow.py:900(op_GET_ITER)
#         1    0.000    0.000    0.000    0.000 byteflow.py:906(op_FOR_ITER)
#         1    0.000    0.000    0.000    0.000 byteflow.py:918(_unaryop)
#        19    0.000    0.000    0.000    0.000 byteflow.py:929(_binaryop)
#         1    0.000    0.000    0.000    0.000 c_ast.py:1012(Typedef)
#         1    0.000    0.000    0.000    0.000 c_ast.py:1032(Typename)
#         1    0.000    0.000    0.000    0.000 c_ast.py:1052(UnaryOp)
#         1    0.000    0.000    0.000    0.000 c_ast.py:1070(Union)
#         1    0.000    0.000    0.000    0.000 c_ast.py:1089(While)
#         1    0.000    0.000    0.000    0.000 c_ast.py:109(NodeVisitor)
#         1    0.000    0.000    0.000    0.000 c_ast.py:1110(Pragma)
#         1    0.000    0.000    0.000    0.000 c_ast.py:167(ArrayDecl)
#         1    0.000    0.000    0.000    0.000 c_ast.py:189(ArrayRef)
#         1    0.000    0.000    0.001    0.001 c_ast.py:19(<module>)
#         1    0.000    0.000    0.000    0.000 c_ast.py:210(Assignment)
#         1    0.000    0.000    0.000    0.000 c_ast.py:232(Alignas)
#         1    0.000    0.000    0.000    0.000 c_ast.py:249(BinaryOp)
#         1    0.000    0.000    0.000    0.000 c_ast.py:271(Break)
#         1    0.000    0.000    0.000    0.000 c_ast.py:285(Case)
#         1    0.000    0.000    0.000    0.000 c_ast.py:30(Node)
#         1    0.000    0.000    0.000    0.000 c_ast.py:307(Cast)
#         1    0.000    0.000    0.000    0.000 c_ast.py:328(Compound)
#         1    0.000    0.000    0.000    0.000 c_ast.py:346(CompoundLiteral)
#         1    0.000    0.000    0.000    0.000 c_ast.py:367(Constant)
#         1    0.000    0.000    0.000    0.000 c_ast.py:384(Continue)
#         1    0.000    0.000    0.000    0.000 c_ast.py:398(Decl)
#         1    0.000    0.000    0.000    0.000 c_ast.py:428(DeclList)
#         1    0.001    0.001    0.001    0.001 c_ast.py:446(Default)
#         1    0.000    0.000    0.000    0.000 c_ast.py:464(DoWhile)
#         1    0.000    0.000    0.000    0.000 c_ast.py:485(EllipsisParam)
#         1    0.000    0.000    0.000    0.000 c_ast.py:499(EmptyStatement)
#         1    0.000    0.000    0.000    0.000 c_ast.py:513(Enum)
#         1    0.000    0.000    0.000    0.000 c_ast.py:531(Enumerator)
#         1    0.000    0.000    0.000    0.000 c_ast.py:549(EnumeratorList)
#         1    0.000    0.000    0.000    0.000 c_ast.py:567(ExprList)
#         1    0.000    0.000    0.000    0.000 c_ast.py:585(FileAST)
#         1    0.000    0.000    0.000    0.000 c_ast.py:603(For)
#         1    0.000    0.000    0.000    0.000 c_ast.py:632(FuncCall)
#         1    0.000    0.000    0.000    0.000 c_ast.py:653(FuncDecl)
#         1    0.000    0.000    0.000    0.000 c_ast.py:674(FuncDef)
#         1    0.000    0.000    0.000    0.000 c_ast.py:700(Goto)
#         1    0.000    0.000    0.000    0.000 c_ast.py:716(ID)
#         1    0.000    0.000    0.000    0.000 c_ast.py:732(IdentifierType)
#         1    0.000    0.000    0.000    0.000 c_ast.py:748(If)
#         1    0.000    0.000    0.000    0.000 c_ast.py:773(InitList)
#         1    0.000    0.000    0.000    0.000 c_ast.py:791(Label)
#         1    0.000    0.000    0.000    0.000 c_ast.py:809(NamedInitializer)
#         1    0.000    0.000    0.000    0.000 c_ast.py:831(ParamList)
#         1    0.000    0.000    0.000    0.000 c_ast.py:849(PtrDecl)
#         1    0.000    0.000    0.000    0.000 c_ast.py:867(Return)
#         1    0.000    0.000    0.000    0.000 c_ast.py:884(StaticAssert)
#         1    0.000    0.000    0.000    0.000 c_ast.py:905(Struct)
#         1    0.000    0.000    0.000    0.000 c_ast.py:924(StructRef)
#         1    0.000    0.000    0.000    0.000 c_ast.py:946(Switch)
#         1    0.000    0.000    0.000    0.000 c_ast.py:967(TernaryOp)
#         1    0.000    0.000    0.000    0.000 c_ast.py:992(TypeDecl)
#         1    0.000    0.000    0.000    0.000 c_lexer.py:15(CLexer)
#         1    0.000    0.000    0.003    0.003 c_lexer.py:9(<module>)
#         1    0.000    0.000    0.000    0.000 c_parser.py:17(CParser)
#         1    0.000    0.000    0.014    0.014 c_parser.py:9(<module>)
#         1    0.000    0.000    0.000    0.000 caching.py:100(save_overload)
#         1    0.000    0.000    0.000    0.000 caching.py:97(load_overload)
#         2    0.000    0.000    0.000    0.000 callconv.py:104(init_call_helper)
#         2    0.000    0.000    0.003    0.002 callconv.py:115(raise_error)
#         2    0.000    0.000    0.000    0.000 callconv.py:145(decode_arguments)
#        16    0.000    0.000    0.001    0.000 callconv.py:154(_get_arg_packer)
#         2    0.000    0.000    0.000    0.000 callconv.py:342(_make_call_helper)
#         4    0.000    0.000    0.000    0.000 callconv.py:345(return_value)
#         4    0.000    0.000    0.003    0.001 callconv.py:352(set_static_user_exc)
#         4    0.000    0.000    0.004    0.001 callconv.py:384(return_user_exc)
#         6    0.000    0.000    0.000    0.000 callconv.py:398(_get_try_state)
#         6    0.000    0.000    0.001    0.000 callconv.py:408(check_try_status)
#         2    0.000    0.000    0.000    0.000 callconv.py:439(return_status_propagate)
#        10    0.000    0.000    0.000    0.000 callconv.py:446(_return_errcode_raw)
#         4    0.000    0.000    0.001    0.000 callconv.py:449(_get_return_status)
#         6    0.000    0.000    0.001    0.000 callconv.py:473(get_function_type)
#         4    0.000    0.000    0.001    0.000 callconv.py:485(decorate_function)
#         4    0.000    0.000    0.000    0.000 callconv.py:491(<listcomp>)
#         7    0.000    0.000    0.000    0.000 callconv.py:510(type_may_always_need_nrt)
#         6    0.000    0.000    0.000    0.000 callconv.py:530(get_arguments)
#        12    0.000    0.000    0.000    0.000 callconv.py:536(_get_return_argument)
#        16    0.000    0.000    0.000    0.000 callconv.py:539(_get_excinfo_argument)
#         4    0.000    0.000    0.002    0.001 callconv.py:542(call_function)
#         2    0.000    0.000    0.000    0.000 callconv.py:570(__init__)
#         2    0.000    0.000    0.002    0.001 callconv.py:573(fp_zero_division)
#         2    0.000    0.000    0.000    0.000 callconv.py:610(create_error_model)
#         6    0.000    0.000    0.000    0.000 callconv.py:97(get_return_type)
#         1    0.000    0.000    0.006    0.006 callwrapper.py:101(build)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:11(__init__)
#         1    0.000    0.000    0.006    0.006 callwrapper.py:126(build_wrapper)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:129(<listcomp>)
#         1    0.000    0.000    0.001    0.001 callwrapper.py:183(get_env)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:198(_simplified_return_type)
#         1    0.000    0.000    0.001    0.001 callwrapper.py:20(add_arg)
#         2    0.000    0.000    0.000    0.000 callwrapper.py:210(debug_print)
#         2    0.000    0.000    0.000    0.000 callwrapper.py:38(cleanup_arg)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:66(emit_cleanup)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:92(__init__)
#         1    0.000    0.000    0.000    0.000 case.py:398(__init__)
#         6    0.000    0.000    0.000    0.000 case.py:430(addTypeEqualityFunc)
#         1    0.000    0.000    0.000    0.000 cffi_utils.py:184(FFI_from_buffer)
#         1    0.000    0.000    0.000    0.000 cffi_utils.py:204(FFIAttribute)
#        75    0.000    0.000    0.000    0.000 cffi_utils.py:29(is_ffi_instance)
#        75    0.000    0.000    0.001    0.000 cffi_utils.py:39(is_cffi_func)
#         1    0.000    0.000    0.031    0.031 cffi_utils.py:5(<module>)
#         1    0.000    0.000    0.000    0.000 cffiimpl.py:3(<module>)
#        12    0.000    0.000    0.000    0.000 cgutils.py:1100(normalize_ir_text)
#         7    0.000    0.000    0.001    0.000 cgutils.py:124(_make_refs)
#        20    0.000    0.000    0.001    0.000 cgutils.py:142(_get_ptr_by_index)
#        11    0.000    0.000    0.001    0.000 cgutils.py:149(__getattr__)
#        51    0.000    0.000    0.001    0.000 cgutils.py:158(__setattr__)
#        11    0.000    0.000    0.001    0.000 cgutils.py:166(__getitem__)
#         9    0.000    0.000    0.001    0.000 cgutils.py:173(__setitem__)
#         3    0.000    0.000    0.000    0.000 cgutils.py:208(_getvalue)
#         7    0.000    0.000    0.000    0.000 cgutils.py:228(_get_be_type)
#        11    0.000    0.000    0.000    0.000 cgutils.py:231(_cast_member_to_value)
#         9    0.000    0.000    0.000    0.000 cgutils.py:234(_cast_member_from_value)
#         1    0.000    0.000    0.000    0.000 cgutils.py:261(__init__)
#         7    0.000    0.000    0.000    0.000 cgutils.py:308(__setattr__)
#       124    0.001    0.000    0.013    0.000 cgutils.py:362(alloca_once)
#        12    0.000    0.000    0.000    0.000 cgutils.py:411(get_null_value)
#         1    0.000    0.000    0.000    0.000 cgutils.py:415(is_null)
#         4    0.000    0.000    0.000    0.000 cgutils.py:420(is_not_null)
#        10    0.000    0.000    0.000    0.000 cgutils.py:425(if_unlikely)
#         3    0.000    0.000    0.000    0.000 cgutils.py:429(if_likely)
#        13    0.000    0.000    0.000    0.000 cgutils.py:44(make_bytearray)
#         3    0.000    0.000    0.000    0.000 cgutils.py:56(create_struct_proxy)
#         2    0.000    0.000    0.000    0.000 cgutils.py:759(_scalar_pred_against_zero)
#         2    0.000    0.000    0.000    0.000 cgutils.py:770(is_scalar_zero)
#         4    0.000    0.000    0.001    0.000 cgutils.py:829(if_zero)
#         8    0.000    0.000    0.000    0.000 cgutils.py:841(is_pointer)
#        32    0.000    0.000    0.002    0.000 cgutils.py:858(gep_inbounds)
#        32    0.000    0.000    0.002    0.000 cgutils.py:865(gep)
#         1    0.000    0.000    0.000    0.000 cgutils.py:884(pointer_add)
#        17    0.000    0.000    0.000    0.000 cgutils.py:910(global_constant)
#         7    0.000    0.000    0.002    0.000 cgutils.py:99(__init__)
#         1    0.000    0.000    0.001    0.001 cmathdecl.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:13(CMath_unary)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:29(<listcomp>)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:32(CMath_predicate)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:35(<listcomp>)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:39(CMath_isfinite)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:44(Cmath_log)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:47(<listcomp>)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:49(<listcomp>)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:52(Cmath_phase)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:54(<listcomp>)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:58(Cmath_polar)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:68(Cmath_rect)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:70(<listcomp>)
#         1    0.000    0.000    0.001    0.001 cmathimpl.py:3(<module>)
#         4    0.000    0.000    0.000    0.000 cmathimpl.py:93(intrinsic_complex_unary)
# ...
#         7    0.000    0.000    0.000    0.000 weakref.py:341(__init__)
#         1    0.000    0.000    0.000    0.000 weakref.py:356(__init__)
#       774    0.002    0.000    0.005    0.000 weakref.py:395(__getitem__)
#        26    0.000    0.000    0.000    0.000 weakref.py:408(__setitem__)
#         5    0.000    0.000    0.000    0.000 weakref.py:530(__init__)
#         1    0.000    0.000    0.000    0.000 yacc.py:109(PlyLogger)
#         1    0.000    0.000    0.000    0.000 yacc.py:127(NullLogger)
#         1    0.000    0.000    0.000    0.000 yacc.py:1309(Production)
#         1    0.000    0.000    0.000    0.000 yacc.py:135(YaccError)
#         1    0.000    0.000    0.000    0.000 yacc.py:1381(MiniProduction)
#         1    0.000    0.000    0.000    0.000 yacc.py:1427(LRItem)
#         1    0.000    0.000    0.000    0.000 yacc.py:1470(GrammarError)
#         1    0.000    0.000    0.000    0.000 yacc.py:1473(Grammar)
#         1    0.000    0.000    0.000    0.000 yacc.py:1968(VersionError)
#         1    0.000    0.000    0.000    0.000 yacc.py:1971(LRTable)
#         1    0.000    0.000    0.000    0.000 yacc.py:2089(LALRError)
#         1    0.000    0.000    0.000    0.000 yacc.py:2099(LRGeneratedTable)
#         1    0.000    0.000    0.000    0.000 yacc.py:217(YaccSymbol)
#         1    0.000    0.000    0.000    0.000 yacc.py:233(YaccProduction)
#         1    0.000    0.000    0.000    0.000 yacc.py:285(LRParser)
#         1    0.000    0.000    0.000    0.000 yacc.py:2936(ParserReflect)
#         1    0.000    0.000    0.001    0.001 yacc.py:62(<module>)
#      1358    0.010    0.000    0.010    0.000 {built-in method __new__ of type object at 0xa99cc0}
#       537    0.003    0.000    0.003    0.000 {built-in method _abc._abc_init}
#      6360    0.005    0.000    0.014    0.000 {built-in method _abc._abc_instancecheck}
# 2245/1302    0.012    0.000    0.012    0.000 {built-in method _abc._abc_subclasscheck}
#       117    0.000    0.000    0.000    0.000 {built-in method _abc.get_cache_token}
#         1    0.000    0.000    0.000    0.000 {built-in method _cffi_backend._get_common_types}
#         1    0.000    0.000    0.000    0.000 {built-in method _cffi_backend._get_types}
#         1    0.000    0.000    0.000    0.000 {built-in method _cffi_backend.cast}
#         1    0.000    0.000    0.000    0.000 {built-in method _cffi_backend.new_array_type}
#         2    0.000    0.000    0.000    0.000 {built-in method _cffi_backend.new_pointer_type}
#         1    0.000    0.000    0.000    0.000 {built-in method _cffi_backend.new_primitive_type}
#         1    0.000    0.000    0.000    0.000 {built-in method _cffi_backend.new_void_type}
#         8    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#        62    0.000    0.000    0.000    0.000 {built-in method _ctypes.byref}
#        12    0.000    0.000    0.000    0.000 {built-in method _ctypes.sizeof}
#       922    0.001    0.000    0.001    0.000 {built-in method _functools.reduce}
#         4    0.000    0.000    0.000    0.000 {built-in method _hashlib.openssl_sha1}
#        94    0.000    0.000    0.000    0.000 {built-in method _imp._fix_co_filename}
#      1071    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.create_builtin}
#        17    0.016    0.001    0.016    0.001 {built-in method _imp.create_dynamic}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.exec_builtin}
#     17/14    0.006    0.000    0.008    0.001 {built-in method _imp.exec_dynamic}
#         3    0.000    0.000    0.000    0.000 {built-in method _imp.is_builtin}
#       114    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#      1071    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#        21    0.000    0.000    0.000    0.000 {built-in method _sre.compile}
#        52    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_iscased}
#        42    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_tolower}
#        36    0.000    0.000    0.000    0.000 {built-in method _struct.pack}
#         9    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#       232    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#       294    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#       559    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#        51    0.000    0.000    0.000    0.000 {built-in method _warnings.warn}
#         5    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#       540    0.005    0.000    0.014    0.000 {built-in method builtins.__build_class__}
#     55/30    0.000    0.000    0.142    0.005 {built-in method builtins.__import__}
#       465    0.000    0.000    0.001    0.000 {built-in method builtins.all}
# 1113/1106    0.001    0.000    0.003    0.000 {built-in method builtins.any}
#        23    0.000    0.000    0.000    0.000 {built-in method builtins.bin}
#       453    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.delattr}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.dir}
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.eval}
#     102/1    0.001    0.000    1.068    1.068 {built-in method builtins.exec}
# 6056/6021    0.006    0.000    0.007    0.000 {built-in method builtins.getattr}
#      4983    0.003    0.000    0.004    0.000 {built-in method builtins.hasattr}
# 3063/2781    0.001    0.000    0.001    0.000 {built-in method builtins.hash}
#      1147    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#    104166    0.023    0.000    0.040    0.000 {built-in method builtins.isinstance}
#      2014    0.001    0.000    0.004    0.000 {built-in method builtins.issubclass}
#       466    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 12173/12063    0.002    0.000    0.002    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#       133    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#       419    0.000    0.000    0.000    0.000 {built-in method builtins.min}
# 3216/2908    0.002    0.000    0.016    0.000 {built-in method builtins.next}
#       271    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#       177    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#       281    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#       499    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#  1046/962    0.001    0.000    0.003    0.000 {built-in method builtins.sorted}
#       282    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#        13    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#         1    0.000    0.000    0.000    0.000 {built-in method io.open}
#        94    0.016    0.000    0.016    0.000 {built-in method marshal.loads}
#         1    0.000    0.000    0.000    0.000 {built-in method numba._dynfunc.make_function}
#       923    0.001    0.000    0.001    0.000 {built-in method numba.core.typeconv._typeconv.check_compatible}
#         5    0.000    0.000    0.000    0.000 {built-in method numba.core.typeconv._typeconv.get_pointer}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#       976    0.002    0.000    0.002    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.promote_types}
#       414    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#        13    0.000    0.000    0.000    0.000 {built-in method posix.getcwd}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         7    0.000    0.000    0.000    0.000 {built-in method posix.listdir}
#       358    0.006    0.000    0.006    0.000 {built-in method posix.stat}
#        19    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#        57    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#         7    0.000    0.000    0.000    0.000 {built-in method sys.intern}
#       264    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#       673    0.000    0.000    0.000    0.000 {function _typedict.__getitem__ at 0x7f48bdf363b0}
#        61    0.000    0.000    0.000    0.000 {method '__contains__' of 'frozenset' objects}
#        42    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#         1    0.000    0.000    0.000    0.000 {method '_insert' of '_dispatcher.Dispatcher' objects}
#         2    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#        51    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#      8109    0.002    0.000    0.002    0.000 {method 'add' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#     15394    0.003    0.000    0.003    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'center' of 'str' objects}
#      1330    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#       170    0.000    0.000    0.000    0.000 {method 'clear' of 'frame' objects}
#       511    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#        98    0.000    0.000    0.000    0.000 {method 'copy' of 'set' objects}
#       287    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#       192    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         4    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#       177    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#       223    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#        20    0.000    0.000    0.000    0.000 {method 'end' of 're.Match' objects}
#       215    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'expandtabs' of 'str' objects}
#        30    0.000    0.000    0.000    0.000 {method 'extend' of 'collections.deque' objects}
#     14054    0.002    0.000    0.002    0.000 {method 'extend' of 'list' objects}
#        86    0.000    0.000    0.000    0.000 {method 'find' of 'bytearray' objects}
# 7333/3909    0.009    0.000    0.033    0.000 {method 'format' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'from_address' of '_ctypes.PyCArrayType' objects}
#      4483    0.002    0.000    0.005    0.000 {method 'get' of 'dict' objects}
#        12    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#         4    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#        11    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        22    0.000    0.000    0.000    0.000 {method 'group' of 're.Match' objects}
#         1    0.000    0.000    0.000    0.000 {method 'groups' of 're.Match' objects}
#        12    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#        84    0.000    0.000    0.000    0.000 {method 'index' of 'tuple' objects}
#      1606    0.001    0.000    0.001    0.000 {method 'insert' of 'list' objects}
#       106    0.000    0.000    0.000    0.000 {method 'isalpha' of 'str' objects}
#        20    0.000    0.000    0.000    0.000 {method 'isdigit' of 'str' objects}
#       232    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#      1648    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        59    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
# 3158/3151    0.002    0.000    0.005    0.000 {method 'join' of 'str' objects}
#       345    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#       100    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#       124    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#       112    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'mro' of 'type' objects}
#         2    0.000    0.000    0.000    0.000 {method 'newbyteorder' of 'numpy.generic' objects}
#         3    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#      1865    0.001    0.000    0.001    0.000 {method 'pop' of 'dict' objects}
#      2709    0.001    0.000    0.001    0.000 {method 'pop' of 'list' objects}
#        47    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#        94    0.019    0.000    0.019    0.000 {method 'read' of '_io.FileIO' objects}
#         1    0.001    0.001    0.001    0.001 {method 'readline' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'readlines' of '_io._IOBase' objects}
#        51    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#       187    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#        11    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#       208    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         7    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#        48    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#      1005    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#      2804    0.001    0.000    0.001    0.000 {method 'rstrip' of 'str' objects}
#        14    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'seek' of '_io.BufferedReader' objects}
#         6    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#        78    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#        67    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'startswith' of 'bytes' objects}
#      2668    0.001    0.000    0.001    0.000 {method 'startswith' of 'str' objects}
#        44    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#        22    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#         2    0.000    0.000    0.000    0.000 {method 'tobytes' of 'numpy.generic' objects}
#         4    0.000    0.000    0.000    0.000 {method 'translate' of 'bytearray' objects}
#       715    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       222    0.000    0.000    0.000    0.000 {method 'update' of 'set' objects}
#         8    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#        48    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#      5572    0.001    0.000    0.001    0.000 {method 'values' of 'dict' objects}
#        33    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#        85    0.000    0.000    0.000    0.000 {method 'with_traceback' of 'BaseException' objects}
#        47    0.000    0.000    0.000    0.000 {method 'write' of '_io.BytesIO' objects}
#       570    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %% [markdown]
# When we run the two pieces of code, we notice two things. Firstly, the version with the Numba decortator compiles much faster (when I ran it, about 0.3s compared to about 6s). The second is that the list of called functions is much longer in the compiled version. This is because cProfile has recorded the process of compilation as well as the running of the code. Most of this complexity is simply the detail of the implementation and can be ignored.
#
# The important thing to notice is that Numba was able to speed up the execution of this code significantly with minimal changes to the source code required. This makes Numba a good choice to easily get some extra speed, by compiling heavily used functions in your code.
