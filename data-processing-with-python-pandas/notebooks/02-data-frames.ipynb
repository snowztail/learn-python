# %% [markdown]
# #### Data Processing with Python

# %% [markdown]
# If pandas is installed in your python environment, it's easy to import:

# %%
import pandas as pd

# %% [markdown]
# <hr>
# ##### IN CASE OF PROBLEMS WITH PACKAGES:

# %%
# SOLUTION A: select this cell and type Shift-Enter to execute the code below.

# %conda install pandas

# Now restart the kernel (Menu -> Kernel -> Restart Kernel)

# %%
# SOLUTION B: select this cell and type Shift-Enter to execute the code below.

# %pip install pandas

# Now restart the kernel (Menu -> Kernel -> Restart Kernel)

# %% [markdown]
# <hr>
#
# # 1. DataFrames

# %% [markdown]
# Pandas is built around a fundamental data object called a [DataFrame](https://pandas.pydata.org/pandas-docs/stable/reference/frame.html).
#
# Here's how you can create one from a python [dict](https://docs.python.org/3/tutorial/datastructures.html#dictionaries):

# %%
d = {"a": 1, "b": 2}

# %%
d["b"]
# Out:
# 2

# %%
# Convert dictionary to data frame
planets = pd.DataFrame({ 
    "name" : ["Mercury", "Venus", "Earth", "Mars", "Jupiter", "Saturn", "Uranus", "Neptune"], 
    "type" : ["Terrestrial", "Terrestrial", "Terrestrial", "Terrestrial", "Gas giant", "Gas giant", "Ice giant", "Ice giant"],
    "mass" : [0.0553, 0.815, 1, 0.107, 317.8, 95.2, 14.5, 17.1],
    "diameter" : [0.383, 0.949, 1, 0.532, 11.21, 9.45, 4.01, 3.88],
    "distance from sun" : [0.387, 0.723, 1, 1.52, 5.20, 9.58, 19.2, 30.05],
    "orbital period" : [0.241, 0.615, 1, 1.88, 11.9, 29.4, 83.7, 163.7],
    "rings" : [False, False, False, False, True, True, True, True]
})

planets
# Out:
#       name         type      mass  diameter  distance from sun  \
# 0  Mercury  Terrestrial    0.0553     0.383              0.387
# 1    Venus  Terrestrial    0.8150     0.949              0.723
# 2    Earth  Terrestrial    1.0000     1.000              1.000
# 3     Mars  Terrestrial    0.1070     0.532              1.520
# 4  Jupiter    Gas giant  317.8000    11.210              5.200
# 5   Saturn    Gas giant   95.2000     9.450              9.580
# 6   Uranus    Ice giant   14.5000     4.010             19.200
# 7  Neptune    Ice giant   17.1000     3.880             30.050
#
#    orbital period  rings
# 0           0.241  False
# 1           0.615  False
# 2           1.000  False
# 3           1.880  False
# 4          11.900   True
# 5          29.400   True
# 6          83.700   True
# 7         163.700   True

# %% [markdown]
# The variable `planets` now points to a DataFrame object containing our data. We can get a quick glimpse of the data using the [`head`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html) method, which returns the first five rows:

# %%
planets.head(3)
# Out:
#       name         type    mass  diameter  distance from sun  orbital period  \
# 0  Mercury  Terrestrial  0.0553     0.383              0.387           0.241
# 1    Venus  Terrestrial  0.8150     0.949              0.723           0.615
# 2    Earth  Terrestrial  1.0000     1.000              1.000           1.000
#
#    rings
# 0  False
# 1  False
# 2  False

# %% [markdown]
# The attribute [`shape`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.shape.html) holds the dimensions of the DataFrame as (#rows, #columns) :

# %%
planets.shape

# %% [markdown]
# ***
#
# ## 1.1 Methods and Attributes
#
# To make use of a DataFrame, we need to understand some basic concepts in object-oriented python.
#
# A *method* is a function that is bound to an object. We show that we want to call the method `head` of the object `planets` using a dot: `planets.head()`.
#
# In a similar way, objects can have associated variables called *attributes*, such as `planets.shape`

# %% [markdown]
# A pandas DataFrame has many other useful [methods](https://pandas.pydata.org/pandas-docs/stable/reference/frame.html#computations-descriptive-stats) and [attributes](https://pandas.pydata.org/pandas-docs/stable/reference/frame.html#attributes-and-underlying-data).
#
# ##### *Exercise 1a*
#
# 1. What do the following methods do?
#
# [`tail`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.tail.html),
# [`sample`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html),
# [`describe`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html),
# [`copy`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.copy.html)

# %%
# Attributes
planets.shape

# Methods
planets.head()
# Out:
#       name         type      mass  diameter  distance from sun  \
# 0  Mercury  Terrestrial    0.0553     0.383              0.387
# 1    Venus  Terrestrial    0.8150     0.949              0.723
# 2    Earth  Terrestrial    1.0000     1.000              1.000
# 3     Mars  Terrestrial    0.1070     0.532              1.520
# 4  Jupiter    Gas giant  317.8000    11.210              5.200
#
#    orbital period  rings
# 0           0.241  False
# 1           0.615  False
# 2           1.000  False
# 3           1.880  False
# 4          11.900   True

# %%
planets.tail(2)
# Out:
#       name       type  mass  diameter  distance from sun  orbital period  \
# 6   Uranus  Ice giant  14.5      4.01              19.20            83.7
# 7  Neptune  Ice giant  17.1      3.88              30.05           163.7
#
#    rings
# 6   True
# 7   True

# %%
planets.tail
# Out:
# <bound method NDFrame.tail of       name         type      mass  diameter  distance from sun  \
# 0  Mercury  Terrestrial    0.0553     0.383              0.387
# 1    Venus  Terrestrial    0.8150     0.949              0.723
# 2    Earth  Terrestrial    1.0000     1.000              1.000
# 3     Mars  Terrestrial    0.1070     0.532              1.520
# 4  Jupiter    Gas giant  317.8000    11.210              5.200
# 5   Saturn    Gas giant   95.2000     9.450              9.580
# 6   Uranus    Ice giant   14.5000     4.010             19.200
# 7  Neptune    Ice giant   17.1000     3.880             30.050
#
#    orbital period  rings
# 0           0.241  False
# 1           0.615  False
# 2           1.000  False
# 3           1.880  False
# 4          11.900   True
# 5          29.400   True
# 6          83.700   True
# 7         163.700   True  >

# %%
planets.sample(2)
# Out:
#      name         type    mass  diameter  distance from sun  orbital period  \
# 3    Mars  Terrestrial   0.107     0.532               1.52            1.88
# 6  Uranus    Ice giant  14.500     4.010              19.20           83.70
#
#    rings
# 3  False
# 6   True

# %%
planets.describe()
# Out:
#              mass   diameter  distance from sun  orbital period
# count    8.000000   8.000000           8.000000        8.000000
# mean    55.822163   3.926750           8.457500       36.554500
# std    110.605675   4.227064          10.837813       58.705645
# min      0.055300   0.383000           0.387000        0.241000
# 25%      0.638000   0.844750           0.930750        0.903750
# 50%      7.750000   2.440000           3.360000        6.890000
# 75%     36.625000   5.370000          11.985000       42.975000
# max    317.800000  11.210000          30.050000      163.700000

# %%
p1 = planets.copy()
p1
# Out:
#       name         type      mass  diameter  distance from sun  \
# 0  Mercury  Terrestrial    0.0553     0.383              0.387
# 1    Venus  Terrestrial    0.8150     0.949              0.723
# 2    Earth  Terrestrial    1.0000     1.000              1.000
# 3     Mars  Terrestrial    0.1070     0.532              1.520
# 4  Jupiter    Gas giant  317.8000    11.210              5.200
# 5   Saturn    Gas giant   95.2000     9.450              9.580
# 6   Uranus    Ice giant   14.5000     4.010             19.200
# 7  Neptune    Ice giant   17.1000     3.880             30.050
#
#    orbital period  rings
# 0           0.241  False
# 1           0.615  False
# 2           1.000  False
# 3           1.880  False
# 4          11.900   True
# 5          29.400   True
# 6          83.700   True
# 7         163.700   True

# %%
# Refer to same object: change in planets means change in p2
p2 = planets
p2
# Out:
#       name         type      mass  diameter  distance from sun  \
# 0  Mercury  Terrestrial    0.0553     0.383              0.387
# 1    Venus  Terrestrial    0.8150     0.949              0.723
# 2    Earth  Terrestrial    1.0000     1.000              1.000
# 3     Mars  Terrestrial    0.1070     0.532              1.520
# 4  Jupiter    Gas giant  317.8000    11.210              5.200
# 5   Saturn    Gas giant   95.2000     9.450              9.580
# 6   Uranus    Ice giant   14.5000     4.010             19.200
# 7  Neptune    Ice giant   17.1000     3.880             30.050
#
#    orbital period  rings
# 0           0.241  False
# 1           0.615  False
# 2           1.000  False
# 3           1.880  False
# 4          11.900   True
# 5          29.400   True
# 6          83.700   True
# 7         163.700   True

# %% [markdown]
# 2. To what do the following attributes refer?
#
# [`size`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.size.html),
# [`dtypes`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dtypes.html),
# [`columns`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.columns.html),
# [`values`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.values.html)

# %%
planets.shape
# Out:
# (8, 7)

# %%
planets.size
# Out:
# 56

# %%
planets.dtypes
# Out:
# name                  object
# type                  object
# mass                 float64
# diameter             float64
# distance from sun    float64
# orbital period       float64
# rings                   bool
# dtype: object

# %%
planets.columns
# Out:
# Index(['name', 'type', 'mass', 'diameter', 'distance from sun',
#        'orbital period', 'rings'],
#       dtype='object')

# %%
planets.values
# Out:
# array([['Mercury', 'Terrestrial', 0.0553, 0.383, 0.387, 0.241, False],
#        ['Venus', 'Terrestrial', 0.815, 0.949, 0.723, 0.615, False],
#        ['Earth', 'Terrestrial', 1.0, 1.0, 1.0, 1.0, False],
#        ['Mars', 'Terrestrial', 0.107, 0.532, 1.52, 1.88, False],
#        ['Jupiter', 'Gas giant', 317.8, 11.21, 5.2, 11.9, True],
#        ['Saturn', 'Gas giant', 95.2, 9.45, 9.58, 29.4, True],
#        ['Uranus', 'Ice giant', 14.5, 4.01, 19.2, 83.7, True],
#        ['Neptune', 'Ice giant', 17.1, 3.88, 30.05, 163.7, True]],
#       dtype=object)

# %% [markdown]
# ***
#
# ## 1.2 Accessing Data
#
# Pandas provides several different ways to get data out of the DataFrame.

# %% [markdown]
# ### Accessing single values
#
# A single value can be accessed using [`iat[]`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iat.html).
#
# We can think of it as meaning "the value **at** an **i**nteger position".
#
# It treats the DataFrame like an array with two *axes*.
#
# The row coordinate is the first axis; the column coordinate is second.

# %%
# Remember Python counts from 0
planets.iat[1, 2]
# Out:
# 0.815

# %% [markdown]
# ### Accessing rows and columns
#
# [`iloc[]`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html) means "**loc**ate data by **i**nteger position".
#
# It is used to access subsets of rows and columns, using the same coordinate system as `iat[]`.

# %% [markdown]
# #### Selecting rows
#
# We can use `iloc[]` with a slice to get a subset of __rows:__

# %%
planets.iloc[2:4]
# Out:
#     name         type   mass  diameter  distance from sun  orbital period  \
# 2  Earth  Terrestrial  1.000     1.000               1.00            1.00
# 3   Mars  Terrestrial  0.107     0.532               1.52            1.88
#
#    rings
# 2  False
# 3  False

# %%
mylist = ["a", "b", "c", "d", "e"]

# %%
len(mylist)
# Out:
# 5

# %%
mylist[0:4]
# Out:
# ['a', 'b', 'c', 'd']

# %%
mylist[-2:]
# Out:
# ['d', 'e']

# %%
mylist[-4::2]
# Out:
# ['b', 'd']

# %% [markdown]
# Because *slicing rows* is such a common operation, pandas also provides a shortcut:

# %%
planets[2:4]
# Out:
#     name         type   mass  diameter  distance from sun  orbital period  \
# 2  Earth  Terrestrial  1.000     1.000               1.00            1.00
# 3   Mars  Terrestrial  0.107     0.532               1.52            1.88
#
#    rings
# 2  False
# 3  False

# %% [markdown]
# Alternatively, we can provide `iloc[]` with a list of the indices to select:

# %%
# Advanced slides are not supported by shortcut and require iloc[]
planets.iloc[[1, 3, 5]]
# Out:
#      name         type    mass  diameter  distance from sun  orbital period  \
# 1   Venus  Terrestrial   0.815     0.949              0.723           0.615
# 3    Mars  Terrestrial   0.107     0.532              1.520           1.880
# 5  Saturn    Gas giant  95.200     9.450              9.580          29.400
#
#    rings
# 1  False
# 3  False
# 5   True

# %% [markdown]
# ##### *Exercise 1b*
#
# 1. Select the last three rows.

# %%
planets.tail(3)
# Out:
#       name       type  mass  diameter  distance from sun  orbital period  \
# 5   Saturn  Gas giant  95.2      9.45               9.58            29.4
# 6   Uranus  Ice giant  14.5      4.01              19.20            83.7
# 7  Neptune  Ice giant  17.1      3.88              30.05           163.7
#
#    rings
# 5   True
# 6   True
# 7   True

# %%
planets[-3:]
# Out:
#       name       type  mass  diameter  distance from sun  orbital period  \
# 5   Saturn  Gas giant  95.2      9.45               9.58            29.4
# 6   Uranus  Ice giant  14.5      4.01              19.20            83.7
# 7  Neptune  Ice giant  17.1      3.88              30.05           163.7
#
#    rings
# 5   True
# 6   True
# 7   True

# %% [markdown]
# 2. Select three rows at random.

# %%
planets.sample(3)
# Out:
#       name         type     mass  diameter  distance from sun  orbital period  \
# 6   Uranus    Ice giant  14.5000     4.010             19.200          83.700
# 0  Mercury  Terrestrial   0.0553     0.383              0.387           0.241
# 2    Earth  Terrestrial   1.0000     1.000              1.000           1.000
#
#    rings
# 6   True
# 0  False
# 2  False

# %% [markdown]
# 3. Make a DataFrame containing only the first row.

# %%
planets.head(1)
# Out:
#       name         type    mass  diameter  distance from sun  orbital period  \
# 0  Mercury  Terrestrial  0.0553     0.383              0.387           0.241
#
#    rings
# 0  False

# %%
planets.iloc[[0]]
# Out:
#       name         type    mass  diameter  distance from sun  orbital period  \
# 0  Mercury  Terrestrial  0.0553     0.383              0.387           0.241
#
#    rings
# 0  False

# %%
planets[0:1]
# Out:
#       name         type    mass  diameter  distance from sun  orbital period  \
# 0  Mercury  Terrestrial  0.0553     0.383              0.387           0.241
#
#    rings
# 0  False

# %% [markdown]
# 4. Make a DataFrame containing the first, second and last rows.

# %%
planets.iloc[[0, 1, -1]]
# Out:
#       name         type     mass  diameter  distance from sun  orbital period  \
# 0  Mercury  Terrestrial   0.0553     0.383              0.387           0.241
# 1    Venus  Terrestrial   0.8150     0.949              0.723           0.615
# 7  Neptune    Ice giant  17.1000     3.880             30.050         163.700
#
#    rings
# 0  False
# 1  False
# 7   True

# %% [markdown]
# #### Selecting columns
#
# We can access columns by integer using the second axis of `iloc[]`:

# %%
planets.iloc[:, 2]
# Out:
# 0      0.0553
# 1      0.8150
# 2      1.0000
# 3      0.1070
# 4    317.8000
# 5     95.2000
# 6     14.5000
# 7     17.1000
# Name: mass, dtype: float64

# %%
type(planets.iloc[:, 2])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Using an integer index (e.g. `2` above), this returns the column values in the form of a pandas [Series](https://pandas.pydata.org/pandas-docs/stable/reference/series.html) object.
#
# Here's how to return the same column as a DataFrame:

# %%
planets.iloc[:, [2]]
# Out:
#        mass
# 0    0.0553
# 1    0.8150
# 2    1.0000
# 3    0.1070
# 4  317.8000
# 5   95.2000
# 6   14.5000
# 7   17.1000

# %%
type(planets.iloc[:, [2]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Notice that we still need to provide a placeholder `:` before the comma, to indicate "all of the rows".
#
# Using a slice or list after the comma returns a subset of columns:

# %%
planets.iloc[:, 2:4]
# Out:
#        mass  diameter
# 0    0.0553     0.383
# 1    0.8150     0.949
# 2    1.0000     1.000
# 3    0.1070     0.532
# 4  317.8000    11.210
# 5   95.2000     9.450
# 6   14.5000     4.010
# 7   17.1000     3.880

# %% [markdown]
# However, accessing columns by position is not usually very convenient. We need to be able to refer to the columns by their *labels*.

# %% [markdown]
# ### Accessing by label
# [`loc[]`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html) means "locate by label". Our columns are labelled with strings.

# %%
planets.loc[:, "name"]
# Out:
# 0    Mercury
# 1      Venus
# 2      Earth
# 3       Mars
# 4    Jupiter
# 5     Saturn
# 6     Uranus
# 7    Neptune
# Name: name, dtype: object

# %% [markdown]
# This returns a Series object, which represents the data from a single column. The numbers shown next to the values are the *row labels*.

# %% [markdown]
# As a shortcut, we can also use `[]` with the *column labels* to select specified columns:

# %%
# Index to columns using strings
planets["name"]
# Out:
# 0    Mercury
# 1      Venus
# 2      Earth
# 3       Mars
# 4    Jupiter
# 5     Saturn
# 6     Uranus
# 7    Neptune
# Name: name, dtype: object

# %%
# Index to rows using range arrays
planets[2:3]
# Out:
#     name         type  mass  diameter  distance from sun  orbital period  \
# 2  Earth  Terrestrial   1.0       1.0                1.0             1.0
#
#    rings
# 2  False

# %% [markdown]
# A list can be used to select multiple columns.

# %%
planets[["name", "mass"]]
# Out:
#       name      mass
# 0  Mercury    0.0553
# 1    Venus    0.8150
# 2    Earth    1.0000
# 3     Mars    0.1070
# 4  Jupiter  317.8000
# 5   Saturn   95.2000
# 6   Uranus   14.5000
# 7  Neptune   17.1000

# %% [markdown]
# ##### *Exercise 1c*
#
# 1. Select the first three rows, but only the **name** and **diameter** columns.

# %%
planets[["name", "diameter"]].iloc[0:3]
# Out:
#       name  diameter
# 0  Mercury     0.383
# 1    Venus     0.949
# 2    Earth     1.000

# %%
planets[["name", "diameter"]][0:3]
# Out:
#       name  diameter
# 0  Mercury     0.383
# 1    Venus     0.949
# 2    Earth     1.000

# %% [markdown]
# 2. Select the first two columns for rows 4 and 6.

# %%
planets.iloc[[3, 5], 0:2]
# Out:
#      name         type
# 3    Mars  Terrestrial
# 5  Saturn    Gas giant

# %% [markdown]
# 3. Select all columns from **type** to **diameter** inclusive.

# %%
planets
# Out:
#       name         type      mass  diameter  distance from sun  \
# 0  Mercury  Terrestrial    0.0553     0.383              0.387
# 1    Venus  Terrestrial    0.8150     0.949              0.723
# 2    Earth  Terrestrial    1.0000     1.000              1.000
# 3     Mars  Terrestrial    0.1070     0.532              1.520
# 4  Jupiter    Gas giant  317.8000    11.210              5.200
# 5   Saturn    Gas giant   95.2000     9.450              9.580
# 6   Uranus    Ice giant   14.5000     4.010             19.200
# 7  Neptune    Ice giant   17.1000     3.880             30.050
#
#    orbital period  rings
# 0           0.241  False
# 1           0.615  False
# 2           1.000  False
# 3           1.880  False
# 4          11.900   True
# 5          29.400   True
# 6          83.700   True
# 7         163.700   True

# %%
planets.loc[:, "type" : "diameter"]
# Out:
#           type      mass  diameter
# 0  Terrestrial    0.0553     0.383
# 1  Terrestrial    0.8150     0.949
# 2  Terrestrial    1.0000     1.000
# 3  Terrestrial    0.1070     0.532
# 4    Gas giant  317.8000    11.210
# 5    Gas giant   95.2000     9.450
# 6    Ice giant   14.5000     4.010
# 7    Ice giant   17.1000     3.880

# %%
planets.loc[0:2, "type" : "diameter"]
# Out:
#           type    mass  diameter
# 0  Terrestrial  0.0553     0.383
# 1  Terrestrial  0.8150     0.949
# 2  Terrestrial  1.0000     1.000

# %%
# Not working, as shortcut slides rows
planets["type" : "diameter"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/snowztail/Repositories/learn-python/data-processing-with-python/notebooks/02-data-frames.ipynb Cell 83' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/snowztail/Repositories/learn-python/data-processing-with-python/notebooks/02-data-frames.ipynb#ch0000121?line=0'>1</a> # Not working, as shortcut slides rows
# ----> <a href='vscode-notebook-cell:/home/snowztail/Repositories/learn-python/data-processing-with-python/notebooks/02-data-frames.ipynb#ch0000121?line=1'>2</a> planets["type" : "diameter"]
#
# File /usr/lib/python3.10/site-packages/pandas/core/frame.py:3477, in DataFrame.__getitem__(self, key)
#    3474         return self._get_item_cache(key)
#    3476 # Do we have a slicer (on rows)?
# -> 3477 indexer = convert_to_index_sliceable(self, key)
#    3478 if indexer is not None:
#    3479     if isinstance(indexer, np.ndarray):
#
# File /usr/lib/python3.10/site-packages/pandas/core/indexing.py:2324, in convert_to_index_sliceable(obj, key)
#    2322 idx = obj.index
#    2323 if isinstance(key, slice):
# -> 2324     return idx._convert_slice_indexer(key, kind="getitem")
#    2326 elif isinstance(key, str):
#    2327
#    2328     # we are an actual column
#    2329     if key in obj.columns:
#
# File /usr/lib/python3.10/site-packages/pandas/core/indexes/numeric.py:279, in NumericIndex._convert_slice_indexer(self, key, kind)
#     275     # We always treat __getitem__ slicing as label-based
#     276     # translate to locations
#     277     return self.slice_indexer(key.start, key.stop, key.step)
# --> 279 return super()._convert_slice_indexer(key, kind=kind)
#
# File /usr/lib/python3.10/site-packages/pandas/core/indexes/base.py:4041, in Index._convert_slice_indexer(self, key, kind)
#    4036 """
#    4037 called from the getitem slicers, validate that we are in fact
#    4038 integers
#    4039 """
#    4040 if self.is_integer() or is_index_slice:
# -> 4041     self._validate_indexer("slice", key.start, "getitem")
#    4042     self._validate_indexer("slice", key.stop, "getitem")
#    4043     self._validate_indexer("slice", key.step, "getitem")
#
# File /usr/lib/python3.10/site-packages/pandas/core/indexes/base.py:6308, in Index._validate_indexer(self, form, key, kind)
#    6305 assert kind in ["getitem", "iloc"]
#    6307 if key is not None and not is_integer(key):
# -> 6308     raise self._invalid_indexer(form, key)
#
# TypeError: cannot do slice indexing on RangeIndex with these indexers [type] of type str

# %%
planets.loc[:, "type" : "diameter"].iloc[0:2]
# Out:
#           type    mass  diameter
# 0  Terrestrial  0.0553     0.383
# 1  Terrestrial  0.8150     0.949

# %% [markdown]
# ***
#
# ## 1.3 Querying, filtering and sorting data
#
# Of course, we are not just limited to accessing data by position and label.
#
# Here are some useful DataFrame methods for basic data manipulation:

# %% [markdown]
# ### [`query`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.query.html)
# selects __rows__ according to whatever conditions we specify, e.g.:

# %%
planets.query('name == "Earth"')
# Out:
#     name         type  mass  diameter  distance from sun  orbital period  \
# 2  Earth  Terrestrial   1.0       1.0                1.0             1.0
#
#    rings
# 2  False

# %%
planets.query("diameter > 2")
# Out:
#       name       type   mass  diameter  distance from sun  orbital period  \
# 4  Jupiter  Gas giant  317.8     11.21               5.20            11.9
# 5   Saturn  Gas giant   95.2      9.45               9.58            29.4
# 6   Uranus  Ice giant   14.5      4.01              19.20            83.7
# 7  Neptune  Ice giant   17.1      3.88              30.05           163.7
#
#    rings
# 4   True
# 5   True
# 6   True
# 7   True

# %%
planets.query("`distance from sun` > 2")
# Out:
#       name       type   mass  diameter  distance from sun  orbital period  \
# 4  Jupiter  Gas giant  317.8     11.21               5.20            11.9
# 5   Saturn  Gas giant   95.2      9.45               9.58            29.4
# 6   Uranus  Ice giant   14.5      4.01              19.20            83.7
# 7  Neptune  Ice giant   17.1      3.88              30.05           163.7
#
#    rings
# 4   True
# 5   True
# 6   True
# 7   True

# %% [markdown]
# Note that the query is a Boolean expression, provided as a string `''`.
#
# Inside the query, column names are unquoted and string values are quoted using `""`.
#
# We can refer to columns containing spaces by enclosing them in backticks ` `` `.
#
# We can also refer to variables in the environment using the `@` prefix.

# %%
max_period = 30
planets.query("rings and `orbital period` < @max_period")
# Out:
#       name       type   mass  diameter  distance from sun  orbital period  \
# 4  Jupiter  Gas giant  317.8     11.21               5.20            11.9
# 5   Saturn  Gas giant   95.2      9.45               9.58            29.4
#
#    rings
# 4   True
# 5   True

# %% [markdown]
# ### [`filter`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.filter.html)
#
# extracts a subset of columns by examining their **labels**, e.g.:

# %%
planets.filter(["name", "mass"])
# Out:
#       name      mass
# 0  Mercury    0.0553
# 1    Venus    0.8150
# 2    Earth    1.0000
# 3     Mars    0.1070
# 4  Jupiter  317.8000
# 5   Saturn   95.2000
# 6   Uranus   14.5000
# 7  Neptune   17.1000

# %%
planets[["name", "mass"]]
# Out:
#       name      mass
# 0  Mercury    0.0553
# 1    Venus    0.8150
# 2    Earth    1.0000
# 3     Mars    0.1070
# 4  Jupiter  317.8000
# 5   Saturn   95.2000
# 6   Uranus   14.5000
# 7  Neptune   17.1000

# %% [markdown]
# This is similar to `loc[]` but has some extra pattern-matching powers:

# %%
planets.filter(like="am")
# Out:
#       name  diameter
# 0  Mercury     0.383
# 1    Venus     0.949
# 2    Earth     1.000
# 3     Mars     0.532
# 4  Jupiter    11.210
# 5   Saturn     9.450
# 6   Uranus     4.010
# 7  Neptune     3.880

# %%
planets.filter(regex="^t")
# Out:
#           type
# 0  Terrestrial
# 1  Terrestrial
# 2  Terrestrial
# 3  Terrestrial
# 4    Gas giant
# 5    Gas giant
# 6    Ice giant
# 7    Ice giant

# %% [markdown]
# ### [`sort_values`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html)
#
# returns a copy of the DataFrame, sorted by ascending column value:

# %%
planets.sort_values("diameter")
# Out:
#       name         type      mass  diameter  distance from sun  \
# 0  Mercury  Terrestrial    0.0553     0.383              0.387
# 3     Mars  Terrestrial    0.1070     0.532              1.520
# 1    Venus  Terrestrial    0.8150     0.949              0.723
# 2    Earth  Terrestrial    1.0000     1.000              1.000
# 7  Neptune    Ice giant   17.1000     3.880             30.050
# 6   Uranus    Ice giant   14.5000     4.010             19.200
# 5   Saturn    Gas giant   95.2000     9.450              9.580
# 4  Jupiter    Gas giant  317.8000    11.210              5.200
#
#    orbital period  rings
# 0           0.241  False
# 3           1.880  False
# 1           0.615  False
# 2           1.000  False
# 7         163.700   True
# 6          83.700   True
# 5          29.400   True
# 4          11.900   True

# %% [markdown]
# ...or by descending value using `ascending=False`:

# %%
sorted_planets = planets.sort_values("diameter", ascending=False)

# %%
sorted_planets
# Out:
#       name         type      mass  diameter  distance from sun  \
# 4  Jupiter    Gas giant  317.8000    11.210              5.200
# 5   Saturn    Gas giant   95.2000     9.450              9.580
# 6   Uranus    Ice giant   14.5000     4.010             19.200
# 7  Neptune    Ice giant   17.1000     3.880             30.050
# 2    Earth  Terrestrial    1.0000     1.000              1.000
# 1    Venus  Terrestrial    0.8150     0.949              0.723
# 3     Mars  Terrestrial    0.1070     0.532              1.520
# 0  Mercury  Terrestrial    0.0553     0.383              0.387
#
#    orbital period  rings
# 4          11.900   True
# 5          29.400   True
# 6          83.700   True
# 7         163.700   True
# 2           1.000  False
# 1           0.615  False
# 3           1.880  False
# 0           0.241  False

# %%
# Refer to indexes, not working once indexes have changed
sorted_planets.loc[0:3]
# Out:
# Empty DataFrame
# Columns: [name, type, mass, diameter, distance from sun, orbital period, rings]
# Index: []

# %%
sorted_planets.reset_index()
# Out:
#    index     name         type      mass  diameter  distance from sun  \
# 0      4  Jupiter    Gas giant  317.8000    11.210              5.200
# 1      5   Saturn    Gas giant   95.2000     9.450              9.580
# 2      6   Uranus    Ice giant   14.5000     4.010             19.200
# 3      7  Neptune    Ice giant   17.1000     3.880             30.050
# 4      2    Earth  Terrestrial    1.0000     1.000              1.000
# 5      1    Venus  Terrestrial    0.8150     0.949              0.723
# 6      3     Mars  Terrestrial    0.1070     0.532              1.520
# 7      0  Mercury  Terrestrial    0.0553     0.383              0.387
#
#    orbital period  rings
# 0          11.900   True
# 1          29.400   True
# 2          83.700   True
# 3         163.700   True
# 4           1.000  False
# 5           0.615  False
# 6           1.880  False
# 7           0.241  False

# %% [markdown]
# The original DataFrame is unchanged:

# %%
planets
# Out:
#       name         type      mass  diameter  distance from sun  \
# 0  Mercury  Terrestrial    0.0553     0.383              0.387
# 1    Venus  Terrestrial    0.8150     0.949              0.723
# 2    Earth  Terrestrial    1.0000     1.000              1.000
# 3     Mars  Terrestrial    0.1070     0.532              1.520
# 4  Jupiter    Gas giant  317.8000    11.210              5.200
# 5   Saturn    Gas giant   95.2000     9.450              9.580
# 6   Uranus    Ice giant   14.5000     4.010             19.200
# 7  Neptune    Ice giant   17.1000     3.880             30.050
#
#    orbital period  rings
# 0           0.241  False
# 1           0.615  False
# 2           1.000  False
# 3           1.880  False
# 4          11.900   True
# 5          29.400   True
# 6          83.700   True
# 7         163.700   True

# %% [markdown]
# ##### *Exercise 1d*
#
# Use manipulations of `planets` to make DataFrames containing the following:

# %% [markdown]
# 1. the terrestrial planets, ordered by increasing orbital period.

# %%
planets.query('type == "Terrestrial"').sort_values("orbital period")
# Out:
#       name         type    mass  diameter  distance from sun  orbital period  \
# 0  Mercury  Terrestrial  0.0553     0.383              0.387           0.241
# 1    Venus  Terrestrial  0.8150     0.949              0.723           0.615
# 2    Earth  Terrestrial  1.0000     1.000              1.000           1.000
# 3     Mars  Terrestrial  0.1070     0.532              1.520           1.880
#
#    rings
# 0  False
# 1  False
# 2  False
# 3  False

# %% [markdown]
# 2. the giant planets, ordered from largest to smallest.

# %%
planets.query('type.str.contains("giant")').sort_values("diameter", ascending=False)
# Out:
#       name       type   mass  diameter  distance from sun  orbital period  \
# 4  Jupiter  Gas giant  317.8     11.21               5.20            11.9
# 5   Saturn  Gas giant   95.2      9.45               9.58            29.4
# 6   Uranus  Ice giant   14.5      4.01              19.20            83.7
# 7  Neptune  Ice giant   17.1      3.88              30.05           163.7
#
#    rings
# 4   True
# 5   True
# 6   True
# 7   True

# %%
planets.query('type == "Gas giant" or type == "Ice giant"').sort_values('diameter', ascending=False)
# Out:
#       name       type   mass  diameter  distance from sun  orbital period  \
# 4  Jupiter  Gas giant  317.8     11.21               5.20            11.9
# 5   Saturn  Gas giant   95.2      9.45               9.58            29.4
# 6   Uranus  Ice giant   14.5      4.01              19.20            83.7
# 7  Neptune  Ice giant   17.1      3.88              30.05           163.7
#
#    rings
# 4   True
# 5   True
# 6   True
# 7   True

# %%
planets.query('type in ["Gas giant", "Ice giant"]').sort_values('diameter', ascending=False)
# Out:
#       name       type   mass  diameter  distance from sun  orbital period  \
# 4  Jupiter  Gas giant  317.8     11.21               5.20            11.9
# 5   Saturn  Gas giant   95.2      9.45               9.58            29.4
# 6   Uranus  Ice giant   14.5      4.01              19.20            83.7
# 7  Neptune  Ice giant   17.1      3.88              30.05           163.7
#
#    rings
# 4   True
# 5   True
# 6   True
# 7   True

# %% [markdown]
# 3. the planets that are more massive than Neptune.

# %%
planets.query('name == "Neptune"').filter(["mass"])
# Out:
#    mass
# 7  17.1

# %%
mass_neptune = planets.query('name == "Neptune"').filter(["mass"]).values[0, 0]
mass_neptune
# Out:
# 17.1

# %%
mass_neptune_ = planets.query('name == "Neptune"')["mass"].values[0]
mass_neptune_
# Out:
# 17.1

# %%
planets.query("mass > @mass_neptune")
# Out:
#       name       type   mass  diameter  distance from sun  orbital period  \
# 4  Jupiter  Gas giant  317.8     11.21               5.20            11.9
# 5   Saturn  Gas giant   95.2      9.45               9.58            29.4
#
#    rings
# 4   True
# 5   True

# %% [markdown]
# ***
#
# ## 1.4 Making new columns from existing ones
#
# It's easy to add a new column to a DataFrame. We just use `[]=` to assign a Series to a new column label:

# %%
df = planets.copy()
df["radius"] = df["diameter"] / 2
df
# Out:
#       name         type      mass  diameter  distance from sun  \
# 0  Mercury  Terrestrial    0.0553     0.383              0.387
# 1    Venus  Terrestrial    0.8150     0.949              0.723
# 2    Earth  Terrestrial    1.0000     1.000              1.000
# 3     Mars  Terrestrial    0.1070     0.532              1.520
# 4  Jupiter    Gas giant  317.8000    11.210              5.200
# 5   Saturn    Gas giant   95.2000     9.450              9.580
# 6   Uranus    Ice giant   14.5000     4.010             19.200
# 7  Neptune    Ice giant   17.1000     3.880             30.050
#
#    orbital period  rings  radius
# 0           0.241  False  0.1915
# 1           0.615  False  0.4745
# 2           1.000  False  0.5000
# 3           1.880  False  0.2660
# 4          11.900   True  5.6050
# 5          29.400   True  4.7250
# 6          83.700   True  2.0050
# 7         163.700   True  1.9400

# %%
planets
# Out:
#       name         type      mass  diameter  distance from sun  \
# 0  Mercury  Terrestrial    0.0553     0.383              0.387
# 1    Venus  Terrestrial    0.8150     0.949              0.723
# 2    Earth  Terrestrial    1.0000     1.000              1.000
# 3     Mars  Terrestrial    0.1070     0.532              1.520
# 4  Jupiter    Gas giant  317.8000    11.210              5.200
# 5   Saturn    Gas giant   95.2000     9.450              9.580
# 6   Uranus    Ice giant   14.5000     4.010             19.200
# 7  Neptune    Ice giant   17.1000     3.880             30.050
#
#    orbital period  rings
# 0           0.241  False
# 1           0.615  False
# 2           1.000  False
# 3           1.880  False
# 4          11.900   True
# 5          29.400   True
# 6          83.700   True
# 7         163.700   True

# %% [markdown]
# Note that Series objects combine in a row-wise manner, similar to numpy arrays, e.g.:

# %%
planets["name"] + " -- " + planets["type"]
# Out:
# 0    Mercury -- Terrestrial
# 1      Venus -- Terrestrial
# 2      Earth -- Terrestrial
# 3       Mars -- Terrestrial
# 4      Jupiter -- Gas giant
# 5       Saturn -- Gas giant
# 6       Uranus -- Ice giant
# 7      Neptune -- Ice giant
# dtype: object

# %% [markdown]
# ##### *Exercise 1e*
#
# Add a new column to `planets` to show the density of each planet relative to Earth.

# %%
planets
# Out:
#       name         type      mass  diameter  distance from sun  \
# 0  Mercury  Terrestrial    0.0553     0.383              0.387
# 1    Venus  Terrestrial    0.8150     0.949              0.723
# 2    Earth  Terrestrial    1.0000     1.000              1.000
# 3     Mars  Terrestrial    0.1070     0.532              1.520
# 4  Jupiter    Gas giant  317.8000    11.210              5.200
# 5   Saturn    Gas giant   95.2000     9.450              9.580
# 6   Uranus    Ice giant   14.5000     4.010             19.200
# 7  Neptune    Ice giant   17.1000     3.880             30.050
#
#    orbital period  rings
# 0           0.241  False
# 1           0.615  False
# 2           1.000  False
# 3           1.880  False
# 4          11.900   True
# 5          29.400   True
# 6          83.700   True
# 7         163.700   True

# %%
import math

planets_ = planets.copy()
planets_["volume"] = 4 / 3 * math.pi * (planets_["diameter"] / 2) ** 3
planets_["density"] = planets_["mass"] / planets_["volume"]
planets_
# Out:
#       name         type      mass  diameter  distance from sun  \
# 0  Mercury  Terrestrial    0.0553     0.383              0.387
# 1    Venus  Terrestrial    0.8150     0.949              0.723
# 2    Earth  Terrestrial    1.0000     1.000              1.000
# 3     Mars  Terrestrial    0.1070     0.532              1.520
# 4  Jupiter    Gas giant  317.8000    11.210              5.200
# 5   Saturn    Gas giant   95.2000     9.450              9.580
# 6   Uranus    Ice giant   14.5000     4.010             19.200
# 7  Neptune    Ice giant   17.1000     3.880             30.050
#
#    orbital period  rings      volume   density
# 0           0.241  False    0.029417  1.879880
# 1           0.615  False    0.447504  1.821211
# 2           1.000  False    0.523599  1.909859
# 3           1.880  False    0.078838  1.357220
# 4          11.900   True  737.590747  0.430862
# 5          29.400   True  441.869523  0.215448
# 6          83.700   True   33.762278  0.429473
# 7         163.700   True   30.583966  0.559117

# %%
density_earth = planets_.query('name == "Earth"')["density"].values[0]
planets_["relative density to earth"] = planets_["density"] / density_earth
planets_ = planets_.round(3)
planets_
# Out:
#       name         type     mass  diameter  distance from sun  orbital period  \
# 0  Mercury  Terrestrial    0.055     0.383              0.387           0.241
# 1    Venus  Terrestrial    0.815     0.949              0.723           0.615
# 2    Earth  Terrestrial    1.000     1.000              1.000           1.000
# 3     Mars  Terrestrial    0.107     0.532              1.520           1.880
# 4  Jupiter    Gas giant  317.800    11.210              5.200          11.900
# 5   Saturn    Gas giant   95.200     9.450              9.580          29.400
# 6   Uranus    Ice giant   14.500     4.010             19.200          83.700
# 7  Neptune    Ice giant   17.100     3.880             30.050         163.700
#
#    rings   volume  density  relative density to earth
# 0  False    0.029    1.880                      0.984
# 1  False    0.448    1.821                      0.954
# 2  False    0.524    1.910                      1.000
# 3  False    0.079    1.357                      0.711
# 4   True  737.591    0.431                      0.226
# 5   True  441.870    0.215                      0.113
# 6   True   33.762    0.429                      0.225
# 7   True   30.584    0.559                      0.293

# %% [markdown]
# ***
